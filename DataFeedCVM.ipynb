# %%
from brfinance import CVMAsyncBackend
from datetime import datetime, date
from bs4 import BeautifulSoup

import pandas
import logging
import requests
import re
import warnings
import os

warnings.filterwarnings("ignore")

# %%
class CVM():

    def log_file(self):
        """ ARQUIVO DE LOG DE REFERENCIA
            ARMAZENA TODAS AS INFORMACOES DAS RODAGENS DO DIA
            INFORMACOES, WARNINGS, ERRORS E ETC.
            POR DEFAULT O NOME DO ARQUIVO E RELATIVO AO DIA DA EXECUCAO
        """

        self.logger = logging.getLogger("log_file")
        self.logger.setLevel(logging.INFO)
        try:
            file_handler = logging.FileHandler(f"log_files//{str(date.today())}.log")
        except FileNotFoundError:
            os.mkdir("log_files//")
            file_handler = logging.FileHandler(f"log_files//{str(date.today())}.log")
        formatter = logging.Formatter('%(asctime)s - %(levelname)s > %(message)s')
        file_handler.setFormatter(formatter)
        self.logger.addHandler(file_handler)
        self.logger.info("Inicializando processamento de dados via Feed CVM")
        self.logger.info(f"By Kevin Pergher - GitHub: @KgPergher98 - Dia: {str(date.today())}")

    def __init__(self) -> None:

        # CRIA ARQUIVO DE LOG
        CVM.log_file(self)

        try:
            # INSTANCIA A CLASSE CMV Async
            self.cvm_http_client = CVMAsyncBackend()
            self.logger.info("CVM Async (BrFinance) instanciada com sucesso")
        except Exception as exc:
            self.logger.error(f"CVM Async (BrFinance) nao instanciada - {exc}")

    def get_cvm_categories(self):
        """ EXTRAI AS INFORMAÇÕES DE CATEGORIAS
            I.E. OS TIPOS DE DOCUMENTOS DISPONÍVEIS

            UTILIZA O BrFINANCE E DADOS DA CVM
        """
        categories = self.cvm_http_client.get_consulta_externa_cvm_categories()
        categories = pandas.DataFrame.from_dict(categories, orient = "index").reset_index()
        categories.columns = ["BrFin", "Description"]
        categories.to_csv("feeder_db//CategoriasDocsCVM.txt", index = False)

    def get_cvm_codes(self):
        """ EXTRAI OS CODIGOS CVM + STATUS CVM

            UTILIZA A BIBLIOTECA BrFINANCE E DADOS DA CVM
        """
        codes = self.cvm_http_client.get_cvm_codes()
        codes = pandas.DataFrame.from_dict(codes, orient = "index")
        pattern = r'\((.*?)\)'
        codes[1] = codes[0].str.extract(pattern).fillna("-")
        codes[0] = codes[0].str.replace(pattern, "", regex = True)
        codes = codes.reset_index()
        codes.columns = ["CVMCode", "FirmName", "CVMStatus"]
        codes.to_csv("feeder_db//CodigosDocsCVM.txt", index = False)

    def format_cnpj(original_number):
        # FORMATACAO DE CNPJ
        if original_number != "-":
            formatted_cnpj = original_number[:2] + '.' + original_number[2:5] + '.' 
            return(formatted_cnpj + original_number[5:8] + '/' + original_number[8:12] + '-' + original_number[12:])
        else:
            return(original_number)

    def firms_informations(self, extract_data:bool = True, fetch_data:bool = True, fetch_br_fin:bool = False, 
                           record_file:str = "feeder_db//EmpresasBrasilCVM", merging_files:bool = True, output_merging:str = "feeder_db//Brazil"):

        """ ADQUIRE INFORMAÇÕES DE COMPANHIAS ABERTAS BRASILEIRAS VIA CVM

            REFERENCIA DE SITE: https://cvmweb.cvm.gov.br/SWB/Sistemas/SCW/CPublica/CiaAb/FormBuscaCiaAbOrdAlf.aspx?LetraInicial=3

            EXTRACT_DATA   [BOOL] > EXTRAI OS DADOS EM TABELAS, SEM CABEÇALHO E CRIA ARQUIVO DE REFERENCIA DE DADOS EM FORMATO .TXT
            FETCH_DATA     [BOOL] > AJUSTA DATAFRAME DE REFERÊNCIA CVM
            FETCH_BR_FIN   [BOOL] > VERIFICA AS INFORMAÇÕES PRESENTES NA LIB BR_FINANCE
            RECORD_FILE    [STR]  > ARQUIVO DE REFERENCIA DOS DADOS DO RED/CVM
            MERGING_FILES  [BOOL] > CONCATENAR INFORMACOES CVM - CNPJ - INFOS ADICIONAIS
            OUTPUT_MERGING [STR]  > ARQUIVO DE SAIDA COM TODAS AS INFORMACOES NECESSARIAS DO ATIVO
        """

        self.logger.info(f"CVM.FirmsInformations() > Extract_Data [Bool]: {extract_data}")
        self.logger.info(f"CVM.FirmsInformations() > Fetch_Data [Bool]: {fetch_data}")
        self.logger.info(f"CVM.FirmsInformations() > Fetch_Br_Fin [Bool]: {fetch_br_fin}")
        self.logger.info(f"CVM.FirmsInformations() > Record_File [Str]: {record_file}")
        self.logger.info(f"CVM.FirmsInformations() > Merging_Files [Str]: {merging_files}")
        self.logger.info(f"CVM.FirmsInformations() > Output_Merging [Str]: {output_merging}")

        if extract_data:
            self.logger.info(f"CVM.FirmsInformations() > Iniciando processo de AQUISICAO DE DADOS")

            # INFORMAÇÕES SOBRE AS COMPANHIAS BRASILEIRAS
            infos = []

            # TODAS AS LETRAS MAIUSCULAS E NUMEROS
            # CONFORME MOSTRADO NO BUSCADOR DA CVM
            capital_letters_and_numbers = []

            # TODAS AS LETRAS MAIUSCULAS VIA ASCII
            for ascii_value in range(ord('A'), ord('Z') + 1):
                capital_letters_and_numbers.append(chr(ascii_value))

            # TODOS OS DIGITOS POSSIVEIS
            for digit in range(10):
                capital_letters_and_numbers.append(str(digit))

            # PARA CADA POSSIBILIDADE NAS LISTAS CRIADAS
            # TENTAMOS ACESSAR AS TABELAS DISPONIVEIS
            for focus in capital_letters_and_numbers:

                # USA O SITE BASE DA CVM E ALTERA A LETRA INICIAL PARA BUSCAR AS TABELAS
                url = f'https://cvmweb.cvm.gov.br//SWB//Sistemas//SCW//CPublica//CiaAb//FormBuscaCiaAbOrdAlf.aspx?LetraInicial={focus}'
                self.logger.info(f"CVM.FirmsInformations() > Buscando empresas em {focus}")

                # USA O REQUEST PARA ACESSAR A URL
                response = requests.get(url)

                # SE O STATUS CODE = 200, ACESSO FOI UM SUCESSO
                if response.status_code == 200:

                    try:

                        # REALIZA O PARSING DO HTML VIA BEAUTIFULSOUP
                        html_content = response.text
                        soup = BeautifulSoup(html_content, 'html.parser')
                        # TODAS AS TABELAS NO HTML
                        tables = soup.find_all('table')

                        for table in tables:

                            # PROCESSAMOS OS ELEMENTOS 'TABELA'
                            rows = table.find_all('tr')

                            for row in rows:

                                # CÉLULAS DA TABELA
                                cells = row.find_all(['th', 'td'])
                                # TEXTO COMPLETO DE INFORMAÇÕES A SER EXTRAÍDO
                                full_txt = ""

                                for cell in cells:

                                    # ADQUIRE O TEXTO, SEM ESPAÇOS
                                    txt = cell.get_text(strip = True)

                                    if not txt.startswith(("CNPJ", "Selecione", " ")):
                                        # NÃO DESEJAMOS OS CABEÇALHOS PADRÃO
                                        full_txt += txt + ";"
                                    else: break

                                # CASO O TEXTO SEJA VALIDO, ACRESCENTA O ARQUIVO EMPRESAS BRASIL
                                if len(full_txt) > 0:
                                    infos.append(full_txt)                     

                    except Exception as exc:
                        # NOS AJUDA A COMPREENDER SE HOUVE UM ERRO E PORQUE
                        self.logger.error(f"CVM.FirmsInformations() > Excessao: {exc} em {focus}")

                else:
                    # NÃO FOI POSSIVEL REALIZAR O REQUEST
                    self.logger.error(f"CVM.FirmsInformations() > Problema Request: {response.status_code} em {focus}")

            # CRIA O ARQUIVO FINAL DE INFORMAÇÕES
            with open(record_file + ".txt", "w+") as record:
                for info in infos:
                    try:
                        self.logger.info(f"CVM.FirmsInformations() > Adicionando info {info} em {record_file}")
                        record.write(info + "\n")
                    except Exception as exc:
                        self.logger.error(f"CVM.FirmsInformations() > Problemas adicionando info {info} em {record_file}, {exc}")

        if fetch_data:

            def format_number(number):
                # MESMA REFERÊNCIA DE FORMATO UTILIZADA PELO BrFINANCE
                return f'{number:06d}'

            self.logger.info(f"CVM.FirmsInformations() > Iniciando processo de AJUSTE DE DADOS CVM")
            # EXTRAI O DATAFRAME DE INFORMAÇÕES DA CVM
            df = pandas.read_csv(
                record_file + ".txt", sep = ";", encoding = "latin1", header = None
            ).dropna(axis = 1)
            # NOME PADRÃO DAS COLUNAS
            df.columns = ["CNPJ", "FIRM_NAME", "CVM_FIRM_TYPE", "CVM_CODE", "CVM_STATUS"]
            # CORRIGE OS CÓDIGOS
            df["CVM_CODE"] = df["CVM_CODE"].apply(format_number)
            # SOBSCREVE AS INFORMAÇÕES
            df.to_csv(record_file + ".txt", index = False)
            self.logger.info(f"CVM.FirmsInformations() > Arquivo {record_file} sobreescrito")

        if fetch_br_fin:
            CVM.get_cvm_codes(self)
            CVM.get_cvm_categories(self)

        if merging_files:

            def for_col(df):
                x = pandas.DataFrame("-", index = ["x"], columns = df.columns)
                for col in df.columns:
                    y = df[col].unique().tolist()
                    if len(y) == 1: 
                        x.loc["x",col] = y[0]
                    else:
                        x.loc["x",col] = ';'.join(y)
                return(x)

            self.logger.info(f"CVM.FirmsInformations() > Iniciando processo de MERGING DE INFORMACOES")
            # DADOS DE PROVEDOR
            self.logger.info(f"CVM.FirmsInformations() > Adquirindo dados relacionais de provedor")
            data_provedor = pandas.read_csv("feeder_db//informacoes_acoes_brasil.csv", encoding = "utf-8", sep = ";", dtype=str)
            data_provedor["CNPJ"] = data_provedor["CNPJ"].str.replace(",", "", regex = False)
            data_provedor["CNPJ"][data_provedor["CNPJ"] != "-"] = data_provedor["CNPJ"].str.zfill(14)
            data_provedor["CNPJ"] = data_provedor["CNPJ"].astype(str).apply(CVM.format_cnpj)
            data_provedor.drop(["Nome.1"], axis = 1, inplace = True)
            data_provedor.columns = ["NAME", "CLASS", "CODE", "CNPJ", "STOCK_TYPE", "ISIN", "SETOR(BOVESPA)", "SUBSETOR(BOVESPA)", "SEGMENTO(BOVESPA)"]
            data_provedor = data_provedor[~(data_provedor.CODE.str.strip().str.contains(" "))]
            data_provedor.CNPJ[(data_provedor.CNPJ == "-")] = data_provedor.CODE
            #data_provedor = data_provedor.map(lambda x: x.upper() if isinstance(x, str) else x)
            for c in data_provedor.columns: data_provedor[c] = data_provedor[c].astype(str).str.upper()

            dataset = pandas.DataFrame("-", index = data_provedor.CNPJ.unique(), columns = data_provedor.columns)
            for cnpj in dataset.index:
                aux_df = data_provedor[data_provedor.CNPJ == cnpj]
                if aux_df.shape[0] == 1:
                    dataset.loc[cnpj,:] = aux_df.iloc[0,:].tolist()
                else:
                    dataset.loc[cnpj,:] = for_col(df = aux_df).iloc[0,:].tolist()
            # DADOS RAD/CVM
            self.logger.info(f"CVM.FirmsInformations() > Adquirindo dados relacionais da CVM")
            empresas_cvm = pandas.read_csv("feeder_db//EmpresasBrasilCVM.txt")
            empresas_cvm["CVM_CODE"] = empresas_cvm["CVM_CODE"].astype(str).str.zfill(6)
            empresas_cvm["SOURCE_CVM"] = True

            # DADOS RAD/CVM
            self.logger.info(f"CVM.FirmsInformations() > Adquirindo dados relacionais via BrFin")
            brfin = pandas.read_csv("feeder_db//CodigosDocsCVM.txt")
            brfin["CVMCode"] = brfin["CVMCode"].astype(str).str.zfill(6)
            brfin.drop(["CVMStatus"], axis = 1, inplace = True)
            brfin.columns = ["CVM_CODE", "FIRM_NAME"]
            brfin["SOURCE_BRFIN"] = True

            df = pandas.concat([empresas_cvm, brfin[~brfin.CVM_CODE.isin(empresas_cvm.CVM_CODE)]], axis = 0)
            df.SOURCE_BRFIN[(df.CVM_CODE.isin(brfin.CVM_CODE)) & (pandas.isna(df.CVM_CODE))] = True
            df.SOURCE_CVM[pandas.isna(df["SOURCE_CVM"])] = False
            df.SOURCE_BRFIN[pandas.isna(df["SOURCE_BRFIN"])] = False
            for c in df.columns:
                df[c][pandas.isna(df[c])] = "-"

            data = dataset.copy()
            data.index = dataset.CNPJ

            data["CVM_CODE"] = "-"
            data["CVM_STATUS"] = "-"
            data["CVM_FIRM_TYPE"] = "-"
            data["FIRM_NAME"] = "-"
            data["SOURCE_ECONOMATICA"] = True
            data["SOURCE_CVM"] = False
            data["SOURCE_BRFIN"] = False

            fetch_cols = ["CVM_CODE", "CVM_STATUS", "CVM_FIRM_TYPE", "FIRM_NAME", "SOURCE_CVM", "SOURCE_BRFIN"]

            df_in = df[(df.CNPJ.isin(data.index)) & (df.CNPJ != "-")]
            df_in.index = df_in.CNPJ

            data.loc[df_in.index, fetch_cols] = df_in[fetch_cols].values
            data.to_csv(output_merging + ".txt", index = False)
            self.logger.info(f"CVM.FirmsInformations() > Base de dados geral gerada em {output_merging}")

    def get_selected_firms(self):

        df = pandas.read_csv("feeder_db//Brazil.txt")
        df = df[(df.CNPJ != "-") & (df.CVM_CODE != "-")]
        self.firms = df.copy()
    
    def list_documents_cvm(self, start_date = date(1995,12,31)):

        # EMPRESAS DE INTERESSE
        CVM.get_selected_firms(self)
        self.logger.info(f"CVM.ListDocumentsCVM() > Listagem de documentos das empresas da bolsa")
        # CATEGORIAS DE DOCUMENTOS DE INTERESSE
        categories = pandas.read_csv("feeder_db//CategoriasDocsCVM.txt")["BrFin"].tolist()
        self.logger.info(f"CVM.ListDocumentsCVM() > Total de categorias de documentos analisadas: {len(categories)}")
        
        # PASTA DE REFERENCIA DE DOCUMENTOS CVM
        if not os.path.isdir("cvm//"):
            os.mkdir("cvm//")
            existing_files = []
            self.logger.info(f"CVM.ListDocumentsCVM() > Diretorio 'cvm' criado")
        else:
            existing_files = os.listdir("cvm//")

        for cvm_code in self.firms["CVM_CODE"].unique():
            # PARA CADA EMPRESA NA ANALISE
            got = False
            retries = 0
            # LACO DE RETRIES (TENTA EXTRAIR MAIS DE UMA VEZ OS RESULTADOS)
            while not got:
                try:
                    if retries < 3:
                        # EXTRACAO DOS DADOS DE INTERESSE
                        # REFERENCIA DE DOCUMENTOS
                        search_result = self.cvm_http_client.get_consulta_externa_cvm_results(
                            start_date = start_date,
                            end_date = date.today(),
                            cod_cvm = [cvm_code],
                            participant_type = [1],
                            category = categories,
                            last_ref_date = False
                        )
                        if f"Docs_CVM_{cvm_code}.txt" in existing_files:
                            # INFORMACOES JA EXISTENTES ACERCA DO ATIVO
                            previous_infos = pandas.read_csv(f"cvm//Docs_CVM_{cvm_code}.txt")
                            # MERGING
                            search_result = pandas.concat([
                                previous_infos,
                                search_result
                            ], axis = 0)
                            search_result.drop_duplicates(inplace = True)
                        # ADICIONA OS ARQUIVOS NA PASTA CVM
                        search_result.to_csv(f"cvm//Docs_CVM_{cvm_code}.txt")
                        self.logger.info(f"CVM.ListDocumentsCVM() > Dados armazenados com sucesso - Docs_CVM_{cvm_code}.txt")
                    # ENCERRA O LACO
                    got = True
                except Exception as exc:
                    # ERRO NA EXTRACAO DOS DADOS, TENTAMOS MAIS N VEZES
                    retries += 1
                    self.logger.warning(f"CVM.ListDocumentsCVM() > Problemas na extracao, codigo {cvm_code} - Tentativa: {retries} - Erro: {exc}")


    def get_reports(self, search = [], to_folder = "reports_cvm//", from_tickers = False):

        def append_file(df, file_name = ""):
            if os.path.isfile(file_name):
                #old_df = pandas.read_csv(file_name)
                #old_df.reset_index(drop = True, inplace = True)
                df = pandas.concat([
                    pandas.read_csv(file_name),
                    df
                ], axis = 0)
                df.drop_duplicates(inplace = True)
                df.to_csv(file_name, index = False)
            else:
                df.to_csv(file_name, index = False)

        # REPORTS DE INTERESSE
        reports_list = [
            'Balanço Patrimonial Ativo',
            'Balanço Patrimonial Passivo',
            'Demonstração do Resultado',
            'Demonstração do Resultado Abrangente',
            'Demonstração do Fluxo de Caixa',
            'Demonstração das Mutações do Patrimônio Líquido',
            'Demonstração de Valor Adicionado']
        
        # SIGLAS PARA OS REPORTS DE INTERESSE
        reports_list_resume = [
            'BALANCO_PATRIMONIAL_ATIVO', 
            'BALANCO_PATRIMONIAL_PASSIVO', 
            'DEMONSTRACAO_RESULTADO', 
            'DEMONSTRACAO_RESULTADO_ABRANGENTE', 
            'DEMONSTRACAO_FLUXO_CAIXA', 
            'DEMONSTRACAO_MUTUACOES_PATRIMONIO_LIQUIDO', 
            'DEMONSTRACAO_VALOR_ADICIONADO'
        ]

        # EMPRESAS DE INTERESSE
        CVM.get_selected_firms(self)
        self.logger.info(f"CVM.GetReports() > Extraindo relatorios estruturados CVM")

        # PASTAS DE REFERENCIA PARA OS ATIVOS
        if not os.path.isdir(to_folder):
            os.mkdir(to_folder)
            self.logger.info(f"CVM.GetReports() > Criando pasta {to_folder}")
            for report_type in reports_list_resume:
                os.mkdir(f"{to_folder}{report_type}//")
                self.logger.info(f"CVM.GetReports() > Criando pasta {to_folder}{report_type}")

        # ARQUIVO DE CONTROLE - CONTROLA OS ARQUIVOS EM CIRCULACAO
        file_controle = f"DocsList.txt"

        if file_controle in os.listdir(to_folder):
            # LEITURA DO CONTROLE DE DOCUMENTOS
            master = pandas.read_csv(f"{to_folder}{file_controle}", dtype = object)
            self.logger.info(f"CVM.GetReports() > Leitura do arquivo de referencia/controle")
        else:
            # NAO HA DOCUMENTO DE CONTROLE
            master = pandas.DataFrame(columns = ["DOC_ID"])
            self.logger.info(f"CVM.GetReports() > Arquivo de controle/referencia inexistente")

        # CONTROLE DE BUSCA
        if len(search) == 0: search = self.firms["CVM_CODE"].unique().tolist()
        elif from_tickers: 
            search = CVM.get_data_from_tickers(ticker_list = search, data_type = "CVM_CODE", keep = False)
            search = sorted(list(set(search)))
        # MAIS INTUITIVO ACOMPANHAR POR EMPRESA
        firms = CVM.get_data_from_cvm_code(cvm_codes = search, data_type = "FIRM_NAME", keep = True)

        # PARA CADA EMPRESA EM NOSSA LISTA
        for src in range(len(search)):
            cvm_code = search[src]
            frm_code = firms[src]
            print(f"Processo: {src + 1}/{len(search)}, Processando empresa: {frm_code}, CVM: {cvm_code}")

            self.logger.info(f"CVM.GetReports() > Analisando empresa {frm_code}, CVM: {cvm_code}")
            
            # ARQUIVO BR_FINANCE - LISTA TODOS OS DOCUMENTOS EXISTENTES
            file_brfinance = f"cvm//Docs_CVM_{cvm_code}.txt"

            try:
                # LEITURA DOS DOCUMENTOS
                documents = pandas.read_csv(file_brfinance, index_col = [0], dtype = object)
                # AJUSTE DO DATAFRAME DOS DOCUMENTOS
                documents = documents[pandas.to_numeric(documents['numero_seq_documento'], errors = 'coerce').notnull()]
                self.logger.info(f"CVM.GetReports() > Leitura dos dados {to_folder}")
                go_on = True

            except FileNotFoundError:
                # NAO HA DOCUMENTO CVM DE REFERENCIA DE ARQUIVOS
                self.logger.info(f"CVM.GetReports() > Arquivo de referencia {to_folder} nao existe, empresa {frm_code}, referencia {cvm_code}")
                go_on = False

            if go_on:

                for _, row in documents.iterrows():

                    # PARA TODOS OS CASOS VALIDOS, QUAL A CATEGORIA DO REPORT?
                    # A CATEGORIA NOS POLPA ESFORCOS NA BUSCA DOS DOCUMENTOS
                    categoria = row.categoria.split(" ")[0]

                    try:
                        if (categoria in ["DFP", "ITR"]):

                            # DOCUMENTO UNIQUE ID
                            docu_id = f"{cvm_code}-{categoria}-{row.ref_date}-V{row.version}-{row.numero_seq_documento}"

                            # VERIFICANDO SE O ARQUIVO JA NA EXISTE ou ALGUM ARQUIVO FOI MAL EXTRAIDO
                            if not docu_id in master.DOC_ID.tolist():

                                # REALIZA A AQUISICAO DOS REPORTS DAS EMPRESAS VIA CVM
                                reports = self.cvm_http_client.get_report(row["numero_seq_documento"], row["codigo_tipo_instituicao"], reports_list = reports_list)
                                # LISTA DE REPORTS DISPONIVEIS
                                key_list = list(reports.keys())
                                # DESCRITIVO DE REFERENCIA DO DOCUMENTO
                                row_description = pandas.DataFrame(row).transpose()

                            else: key_list = []

                        else: key_list = []

                    except Exception: key_list = [] # EM CASO DE ERRO NAO HA LISTA
                        
                    if len(key_list) > 0:

                        for key in key_list:
                            # NOME DO ARQUIVO DE REFERENCIA
                            docu_file = f"{to_folder}{reports_list_resume[reports_list.index(key)]}//{categoria}-{cvm_code}.txt"
                            #docu_rept = f"{docu_id}-{reports_list_resume[reports_list.index(key)]}"
                            
                            df = reports[key].copy()

                            if key != "Demonstração das Mutações do Patrimônio Líquido":
                                try:
                                    # CASO PADRAO DE REPORT, PROCESSAMENTO SIMPLES
                                    df["x"] = df["Valor"].astype(str) + " " + df["currency_unit"]
                                    # ADICIONAR A REFERENCIA DO CONTA A DESCRICAO SE MOSTROU VITAL EM DESAMBIGUAR
                                    df["Descrição"] = "(" + df["Conta"] + ") " + df["Descrição"]
                                    # PADRONIZA OS NANs
                                    df["x"][df.x.str.startswith("nan ")] = "-"
                                    # O INDICE E A PROPRIA DESCRICAO
                                    df.index = df["Descrição"]
                                    # TRANSFORMA EM LINHA
                                    df = df[["x"]].transpose()
                                    # PADRONIZA UM DUMMY INDEX
                                    row_description.index = ["x"]
                                    # VETOR LINHA A SER ADICIONADO
                                    df = pandas.concat([
                                        pandas.DataFrame([docu_id], columns = ["id"], index = ['x']), row_description, df], 
                                        axis = 1
                                    )
                                    discard_data = False
                                except Exception as exc:
                                    # ARQUIVO CORROMPIDO
                                    discard_data = True
                                    self.logger.error(f"CVM.GetReports() > Arquivo {docu_file} com problemas, ERRO: {exc}, ID: {docu_id}, CVM: {cvm_code}")
                            else:
                                try:
                                    # CASO MATRICIAL DISTINTO, MANTEM A REFERENCIA DE INDICE
                                    df.index = "(" + df["Conta"] + ") " + df["Descrição"]
                                    # TIPAGEM STRING/CHAR
                                    df = df.astype(str)

                                    for c in df.columns:
                                        # CADA COLUNA E PADRONIZADA EM CURRENCY
                                        if c not in ["Descrição", "currency_unit"]:
                                            df[c] = df[c] + " " + df["currency_unit"]

                                    # REDUZ O TAMANHO DO DF COM INFORMACOES NAO NECESSARIAS
                                    df.drop(["Descrição", "currency_unit", "Conta"], axis = 1, inplace = True)
                                    # DATAFRAME AUXILIAR
                                    aux = pandas.DataFrame()

                                    for c in df.columns:
                                        # FORMATO PADRAO DE NANs NO DATAFRAME
                                        df[c][df[c].str.startswith("nan ")] = "-"
                                        aux_c = df[[c]]
                                        # INDEX vs COLUNA
                                        aux_c.index = [i + " | " + c for i in aux_c.index]
                                        # INDEX PADRAO
                                        aux_c.columns = ["x"]
                                        # ACUMULA O RESULTADO
                                        aux = pandas.concat([aux, aux_c], axis = 0)

                                    # VETOR LINHAS A SER ADICIONADO
                                    df = pandas.concat([
                                        pandas.DataFrame([docu_id], columns = ["id"], index = ['x']), row_description, aux.transpose().copy()], 
                                        axis = 1
                                    )
                                    discard_data = False
                                except Exception as exc:
                                    # ARQUIVO CORROMPIDO
                                    discard_data = True
                                    self.logger.error(f"CVM.GetReports() > Arquivo {docu_file} com problemas, ERRO: {exc}, ID: {docu_id}, CVM: {cvm_code}")

                            if not discard_data:

                                docu_infos = pandas.DataFrame(
                                    [docu_id], 
                                    index = ["DOC_ID"],
                                    columns = ["X"]
                                ).transpose()

                                try:

                                    append_file(df = df, file_name = f"{docu_file}")
                                    self.logger.info(f"CVM.GetReports() > Arquivo {docu_file} atualzado")

                                    append_file(df = docu_infos, file_name = f"{to_folder}{file_controle}")
                                    self.logger.info(f"CVM.GetReports() > Atualizacao do controle {to_folder}{file_controle} para {cvm_code}")

                                except Exception as exc:
                                    self.logger.error(f"CVM.GetReports() > {exc} - {docu_file} para {cvm_code}")

    def get_data_from_cvm_code(cvm_codes = [], data_type:str = "FIRM_NAME", keep = False):
        if type(cvm_codes) == str: cvm_codes = [cvm_codes]
        # CONTROLE GERAL DE TICKERS E DADOS
        df = pandas.read_csv("feeder_db//Brazil.txt", sep = ",")
        codes = []
        for cvmc in cvm_codes:
            aux = df[df.CVM_CODE == cvmc]
            if aux.shape[0] > 0: codes.append(aux[[data_type]].iloc[0, 0])
            elif keep: codes.append(-1)
        return codes

    def get_data_from_tickers(ticker_list = [], data_type:str = "CVM_CODE", keep = False):

        """ GET_DATA_FROM_TICKERS()

            TICKER_LIST [STR/LIST]: TICKERS DE INTERESSE
            DATA_TYPE [STR]: DADO DESEJADO
            KEEP: MANTEM A ORDEM DOS DADOS (INCLUI DADOS NAO ENCONTRADOS)
        """

        def find_position_by_ticker(x, ticker_list):
            # CASO QUEIRA APENAS UM TICKER
            if type(ticker_list) == str: ticker_list = [ticker_list]
            # EXPANDE OS POSSIVEIS TICKERS
            finder = x["CODE"].str.split(";", expand = True)
            finder.index = x.index
            # RESULTADOS ESPERADOS
            pos = []
            for ticker in ticker_list:
                # VARIAVEL DE CONTROLE
                gotcha = False
                for c in finder.columns:
                    # EXISTE UMA COLUNA COM TAL TICKER?
                    aux = finder[c][finder[c] == ticker]
                    if aux.shape[0] > 0:
                        # CASO POSITIVO
                        pos.append(aux.index.tolist()[0])
                        gotcha = True
                # CASO NAO TENHA SIDO POSSIVEL ENCONTRAR
                if not gotcha: pos.append(-1)
            return pos

        # CONTROLE GERAL DE TICKERS E DADOS
        df = pandas.read_csv("feeder_db//Brazil.txt", sep = ",")
        # POSICOES ENCONTRADAS
        positions = find_position_by_ticker(x = df, ticker_list = ticker_list)

        codes = []
        for t in positions:
            # EXTRACAO DO DADO DE INTERESSE
            if t != -1: codes.append(df[[data_type]].iloc[t, 0])
            elif keep: codes.append(-1)
        return codes

# %%
cvm = CVM()

""" EXTRACAO DE INFORMACOES IMPORTANTES PARA A EXECUCAO DO PROGRAMA

    EXTRACT_DATA   - SE TRUE, REALIZA O SCRAPING DOS DADOS RAD/CVM
    FETCH_DATA     - SE TRUE, MODIFICACOES NA BASE DE DADOS RAD/CVM (EM PROCESSO DE DESCONTINUACAO)
    FETCH_BR_FIN   - SE TRUE, ADQUIRE INFORMACOES IMPORTANTES VIA BrFINANCE
    RECORD_FILE    - ARQUIVO DE REFERENCIA PARA OS DADOS RAD/CVM
    MERGING_FILES  - SE TRUE, REALIZA O MERGING DE TODOS OS ARQUIVOS
    OUTPUT_MERGING - ARQUIVO DE DADOS CONCATENADOS  
"""

#cvm.firms_informations(
#    extract_data = False, 
#    fetch_data = False, 
#    fetch_br_fin = False, 
#    record_file = "feeder_db//EmpresasBrasilCVM", 
#    merging_files = False, 
#    output_merging = "feeder_db//Brazil"
#)

""" REFERENCIA DE DOCUMENTOS CVM

    EXTRAI TODAS AS REFERENCIAS DE DOCUMENTOS CONTIDAS NA CVM PARA EXTRACAO
"""

# TODO FEED CONTINUO QUE EVITA LONGA PESQUISA DE DOCUMENTOS
#cvm.list_documents_cvm()

""" EXTRACAO DOS RELATORIOS ESTRUTURADOS

    APENAS DADOS ESTRUTURADOS VIA MODIFICACAO NO BrFINANCE
"""

cvm.get_reports(search = [], from_tickers = True)
# Out:
# Processo: 1/770, Processando empresa: 3R PETROLEUM OLÉO E GÁS S.A., CVM: 025291
# Processo: 2/770, Processando empresa: TRÊS TENTOS AGROINDUSTRIAL S.A., CVM: 025950
# Processo: 3/770, Processando empresa: 521 PARTICIPAÇOES S.A. - EM LIQUIDAÇÃO EXTRAJUDICIAL, CVM: 016330
# Processo: 4/770, Processando empresa: 524 PARTICIPAÇOES SA, CVM: 016284
# Processo: 5/770, Processando empresa: A.P. PARTICIPAÇOES SA, CVM: 016802
# Processo: 6/770, Processando empresa: BANCO ABC BRASIL S/A, CVM: 020958
# Processo: 7/770, Processando empresa: ABYARA PLANEJAMENTO IMOBILIÁRIO S/A, CVM: 020206
# Processo: 8/770, Processando empresa: ELECTRO AÇO ALTONA S/A, CVM: 005380
# Processo: 9/770, Processando empresa: AÇOS VILLARES SA, CVM: 000108
# Processo: 10/770, Processando empresa: ADVANCED DIGITAL HEALTH MEDICINA PREVENTIVA S.A., CVM: 021725
# Processo: 11/770, Processando empresa: AERIS IND. E COM. DE EQUIP. PARA GER. DE ENG. S.A., CVM: 025283
# Processo: 12/770, Processando empresa: AES Brasil Energia S/A, CVM: 025640
# Processo: 13/770, Processando empresa: AES ELPA SA, CVM: 019313
# Processo: 14/770, Processando empresa: RGE SUL DISTRIBUIDORA DE ENERGIA S.A., CVM: 016527
# Processo: 15/770, Processando empresa: AES TIETE SA, CVM: 018350
# Processo: 16/770, Processando empresa: AES BRASIL OPERAÇÕES S.A., CVM: 026174
# Processo: 17/770, Processando empresa: AETATIS SECURITIZADORA S.A., CVM: 018104
# Processo: 18/770, Processando empresa: AFLUENTE GERAÇÃO DE ENERGIA ELÉTRICA S.A., CVM: 020150
# Processo: 19/770, Processando empresa: AFLUENTE TRANSMISSÃO DE ENERGIA ELETRICA S/A, CVM: 022179
# Processo: 20/770, Processando empresa: ANDRADE GUTIERREZ CONCESSOES SA, CVM: 019437
# Processo: 21/770, Processando empresa: AGF BRASIL SEGUROS SA, CVM: 012343
# Processo: 22/770, Processando empresa: ANDRADE GUTIERREZ PARTICIPAÇÕES SA, CVM: 019062
# Processo: 23/770, Processando empresa: AGRA EMPREENDIMENTOS IMOBILIÁRIOS S/A, CVM: 020664
# Processo: 24/770, Processando empresa: AGRALE SA, CVM: 000183
# Processo: 25/770, Processando empresa: AGRE EMPREENDIMENTOS IMOBILIÁRIOS SA, CVM: 021911
# Processo: 26/770, Processando empresa: HUMBERG AGRIBRASIL COMÉRCIO E EXPORTAÇÃO DE GRÃOS S.A, CVM: 025933
# Processo: 27/770, Processando empresa: SEMENTES AGROCERES SA, CVM: 010570
# Processo: 28/770, Processando empresa: AGROGALAXY PARTICIPAÇÕES S.A, CVM: 025658
# Processo: 29/770, Processando empresa: DANA-ALBARUS S.A. INDÚSTRIA E COMÉRCIO, CVM: 000248
# Processo: 30/770, Processando empresa: CONSORCIO ALFA DE ADMINISTRACAO S.A, CVM: 004707
# Processo: 31/770, Processando empresa: FINANCEIRA ALFA S.A.- C.F.I, CVM: 003891
# Processo: 32/770, Processando empresa: ALFA HOLDINGS S.A., CVM: 009954
# Processo: 33/770, Processando empresa: BANCO ALFA DE INVESTIMENTO S.A., CVM: 001384
# Processo: 34/770, Processando empresa: ALIANSCE SHOPPING CENTERS S/A, CVM: 021300
# Processo: 35/770, Processando empresa: ALIANSCE SONAE SHOPPING CENTERS S.A., CVM: 022357
# Processo: 36/770, Processando empresa: SIDERURGICA J L ALIPERTI SA, CVM: 012823
# Processo: 37/770, Processando empresa: RUMO MALHA NORTE S.A., CVM: 015300
# Processo: 38/770, Processando empresa: ALLIANÇA SAÚDE E PARTICIPAÇÕES S.A., CVM: 024058
# Processo: 39/770, Processando empresa: ALLIED TECNOLOGIA S.A., CVM: 025330
# Processo: 40/770, Processando empresa: ALLIS PARTICIPAÇÕES S.A., CVM: 020850
# Processo: 41/770, Processando empresa: ALPARGATAS SA, CVM: 010456
# Processo: 42/770, Processando empresa: ALPER CONSULTORIA E CORRETORA DE SEGUROS S.A., CVM: 022217
# Processo: 43/770, Processando empresa: ALPHAVILLE S.A., CVM: 025275
# Processo: 44/770, Processando empresa: ALTERE SECURITIZADORA S.A., CVM: 018066
# Processo: 45/770, Processando empresa: ALTUS SISTEMA DE AUTOMAÇÃO S.A., CVM: 023183
# Processo: 46/770, Processando empresa: ALUPAR INVESTIMENTO S/A, CVM: 021490
# Processo: 47/770, Processando empresa: ARCELORMITTAL INOX BRASIL S.A., CVM: 002658
# Processo: 48/770, Processando empresa: AMADEO ROSSI SA MET MUNICOES, CVM: 000361
# Processo: 49/770, Processando empresa: BANCO DA AMAZÔNIA S.A., CVM: 000922
# Processo: 50/770, Processando empresa: AMAZONIA CELULAR S/A, CVM: 017280
# Processo: 51/770, Processando empresa: AMBEV S.A., CVM: 023264
# Processo: 52/770, Processando empresa: AMBIPAR PARTICIPAÇÕES E EMPREENDIMENTOS S.A., CVM: 024961
# Processo: 53/770, Processando empresa: AMELCO SA IND ELETRONICA, CVM: 012750
# Processo: 54/770, Processando empresa: BANCO COMERCIAL E DE INVESTIMENTO SUDAMERIS S.A., CVM: 000787
# Processo: 55/770, Processando empresa: AMERICANAS S.A. - EM RECUPERAÇÃO JUDICIAL, CVM: 020990
# Processo: 56/770, Processando empresa: AMIL PARTICIPAÇÕES S/A, CVM: 021172
# Processo: 57/770, Processando empresa: AMPLA ENERGIA E SERVIÇOS S.A., CVM: 003050
# Processo: 58/770, Processando empresa: AMPLA INVESTIMENTOS E SERVIÇOS S/A, CVM: 020214
# Processo: 59/770, Processando empresa: IRONX MINERAÇÃO S/A, CVM: 021458
# Processo: 60/770, Processando empresa: ANHANGUERA EDUCACIONAL PARTICIPAÇÕES S.A., CVM: 018961
# Processo: 61/770, Processando empresa: ANIMA HOLDING S/A, CVM: 023248
# Processo: 62/770, Processando empresa: IND BEBS ANTARCTICA MG SA, CVM: 003581
# Processo: 63/770, Processando empresa: COMPANHIA BRASILEIRA DE BEBIDAS ( Atual demominação  social da Cia Antarctica Paulista IBBC), CVM: 002755
# Processo: 64/770, Processando empresa: IND BEBS ANTARCTICA PARAIBA SA, CVM: 013188
# Processo: 65/770, Processando empresa: IND BEBS ANTARCTICA PIAUI SA, CVM: 006998
# Processo: 66/770, Processando empresa: ARACRUZ CELULOSE S/A, CVM: 000434
# Processo: 67/770, Processando empresa: ARAUCÁRIA PARTICIPAÇÕES SA, CVM: 018651
# Processo: 68/770, Processando empresa: ARCELOR BRASIL S.A., CVM: 003964
# Processo: 69/770, Processando empresa: AREZZO INDÚSTRIA E COMERCIO S/A, CVM: 022349
# Processo: 70/770, Processando empresa: ARMAC LOCAÇÃO, LOGÍSTICA E SERVIÇOS S.A., CVM: 026069
# Processo: 71/770, Processando empresa: ARNO SA, CVM: 000523
# Processo: 72/770, Processando empresa: INDS ARTEB SA, CVM: 015881
# Processo: 73/770, Processando empresa: ARTERIS S.A., CVM: 019771
# Processo: 74/770, Processando empresa: ARTHUR LANGE SA IND E COM, CVM: 000574
# Processo: 75/770, Processando empresa: SENDAS DISTRIBUIDORA S.A., CVM: 025372
# Processo: 76/770, Processando empresa: ATMA PARTICIPACOES S.A. EM RECUPERACAO JUDICIAL, CVM: 019100
# Processo: 77/770, Processando empresa: ATOM EMPREENDIMENTOS E PARTICIPAÇÕES S.A., CVM: 015423
# Processo: 78/770, Processando empresa: AUREN ENERGIA S.A, CVM: 026620
# Processo: 79/770, Processando empresa: AUTOMETAL S/A, CVM: 022381
# Processo: 80/770, Processando empresa: AZEVEDO & TRAVASSOS SA, CVM: 011975
# Processo: 81/770, Processando empresa: AZUL S.A., CVM: 024112
# Processo: 82/770, Processando empresa: BLUE TECH SOLUTIONS EQI S.A., CVM: 012319
# Processo: 83/770, Processando empresa: B3 S.A. - BRASIL, BOLSA, BALCÃO, CVM: 021610
# Processo: 84/770, Processando empresa: BAHEMA EDUCACAO S.A., CVM: 000701
# Processo: 85/770, Processando empresa: BAHEMA EQUIPAMENTOS SA, CVM: 018155
# Processo: 86/770, Processando empresa: CIA BANDEIRANTES ARMS GERAIS, CVM: 002810
# Processo: 87/770, Processando empresa: ALVORADA CARTOES, CREDITO, FINANCIAMENTO E INVESTIMENTO S/A, CVM: 001147
# Processo: 88/770, Processando empresa: BANCO BMG S/A, CVM: 024600
# Processo: 89/770, Processando empresa: BANCO INTER S.A., CVM: 024406
# Processo: 90/770, Processando empresa: BANCO PAN SA, CVM: 021199
# Processo: 91/770, Processando empresa: EDP SÃO PAULO DISTRIBUIÇÃO DE ENERGIA S.A., CVM: 016985
# Processo: 92/770, Processando empresa: UNICARD BANCO MULTIPLO S.A., CVM: 000841
# Processo: 93/770, Processando empresa: BANCO DO ESTADO DE SERGIPE SA, CVM: 001120
# Processo: 94/770, Processando empresa: BANCO DO ESTADO DE SAO PAULO S.A. - BANESPA, CVM: 001112
# Processo: 95/770, Processando empresa: BANCO BANESTADO SA, CVM: 001180
# Processo: 96/770, Processando empresa: BANESTES SA BANCO DO ESTADO DO ESPIRITO SANTO, CVM: 001155
# Processo: 97/770, Processando empresa: BANEX S/A - CRÉDITO, FINANCIAMENTO E INVESTIMENTO, CVM: 008176
# Processo: 98/770, Processando empresa: BANCO DO ESTADO DO PARÁ S/A., CVM: 001171
# Processo: 99/770, Processando empresa: BANCO DO ESTADO DO RIO GRANDE DO SUL SA, CVM: 001210
# Processo: 100/770, Processando empresa: BARDELLA S.A. INDS MECANICAS - EM RECUPERAÇÃO JUDICIAL, CVM: 001520
# Processo: 101/770, Processando empresa: BAUMER SA, CVM: 001562
# Processo: 102/770, Processando empresa: BBM LOGÍSTICA S.A., CVM: 024660
# Processo: 103/770, Processando empresa: BB SEGURIDADE PARTICIPAÇÕES S.A., CVM: 023159
# Processo: 104/770, Processando empresa: BANCO BCN S.A., CVM: 000957
# Processo: 105/770, Processando empresa: BELAPART SA, CVM: 016233
# Processo: 106/770, Processando empresa: BEMATECH  S/A, CVM: 020656
# Processo: 107/770, Processando empresa: BEMOBI MOBILE TECH S.A., CVM: 025500
# Processo: 108/770, Processando empresa: NESBER COMPANHIA INDUSTRIAL, CVM: 001651
# Processo: 109/770, Processando empresa: BETA SA INDUSTRIA E COMERCIO, CVM: 001660
# Processo: 110/770, Processando empresa: BETAPART PARTICIPAÇÕES SA, CVM: 017884
# Processo: 111/770, Processando empresa: BHG S.A. - BRAZIL HOSPITALITY GROUP, CVM: 020907
# Processo: 112/770, Processando empresa: BICICLETAS MONARK SA, CVM: 001694
# Processo: 113/770, Processando empresa: CHINA CONSTRUCTION BANK(BRASIL) BANCO MÚLTIPLO S.A., CVM: 021113
# Processo: 114/770, Processando empresa: BIOBRAS SA, CVM: 001708
# Processo: 115/770, Processando empresa: BIOMM SA, CVM: 019305
# Processo: 116/770, Processando empresa: BIOSEV S.A., CVM: 022845
# Processo: 117/770, Processando empresa: BLAU FARMACÊUTICA S.A., CVM: 024627
# Processo: 118/770, Processando empresa: BLUE TREE HOTELS & RESORTS DO BRASIL SA, CVM: 017760
# Processo: 119/770, Processando empresa: BOA SAFRA SEMENTES S.A, CVM: 025704
# Processo: 120/770, Processando empresa: BOA VISTA SERVIÇOS S.A., CVM: 025135
# Processo: 121/770, Processando empresa: BOMBRIL SA, CVM: 012190
# Processo: 122/770, Processando empresa: BOMPRECO SA SUPERMERCADO DO NE, CVM: 015202
# Processo: 123/770, Processando empresa: BOMPREÇO BAHIA SA, CVM: 014435
# Processo: 124/770, Processando empresa: BONAIRE PARTICIPAÇÕES S.A.- EM LIQUIDAÇÃO, CVM: 016560
# Processo: 125/770, Processando empresa: BOTUCATU TÊXTIL S. A., CVM: 010987
# Processo: 126/770, Processando empresa: BRASIL FERROVIAS S.A., CVM: 017353
# Processo: 127/770, Processando empresa: BR HOME CENTERS S.A., CVM: 023710
# Processo: 128/770, Processando empresa: BR MALLS PARTICIPAÇOES S.A., CVM: 019909
# Processo: 129/770, Processando empresa: BR ADVISORY PARTNERS PARTICIPACOES S.A., CVM: 025860
# Processo: 130/770, Processando empresa: MASSA FALIDA DA BRASIL PHARMA SA, CVM: 022500
# Processo: 131/770, Processando empresa: BR PROPERTIES S.A., CVM: 019925
# Processo: 132/770, Processando empresa: BANCO BRADESCO S.A., CVM: 000906
# Processo: 133/770, Processando empresa: BRADESPAR S/A, CVM: 018724
# Processo: 134/770, Processando empresa: BRAMPAC SA, CVM: 007714
# Processo: 135/770, Processando empresa: BANCO DO BRASIL S.A., CVM: 001023
# Processo: 136/770, Processando empresa: BRASILAGRO CIA BRAS DE PROP AGRICOLAS, CVM: 020036
# Processo: 137/770, Processando empresa: BRASILIT SA, CVM: 001910
# Processo: 138/770, Processando empresa: BRASKEM S.A., CVM: 004820
# Processo: 139/770, Processando empresa: BRASMOTOR SA, CVM: 001970
# Processo: 140/770, Processando empresa: MASSA FALIDA DE BRASPÉROLA INDÚSTRIA E COMÉRCIO SA, CVM: 003506
# Processo: 141/770, Processando empresa: BRAZILIAN FINANCE & REAL ESTATE S.A., CVM: 017922
# Processo: 142/770, Processando empresa: BRB BANCO DE BRASILIA SA, CVM: 014206
# Processo: 143/770, Processando empresa: BRF S.A., CVM: 016292
# Processo: 144/770, Processando empresa: BRISANET PARTICIPAÇÕES S.A., CVM: 026085
# Processo: 145/770, Processando empresa: BROOKFIELD INCORPORAÇÕES S.A., CVM: 020265
# Processo: 146/770, Processando empresa: BRQ SOLUÇÕES EM INFORMÁTICA S.A., CVM: 023817
# Processo: 147/770, Processando empresa: BRUMADINHO SA MIN E METAIS, CVM: 012971
# Processo: 148/770, Processando empresa: BANCO BTG PACTUAL S/A, CVM: 022616
# Processo: 149/770, Processando empresa: BUETTNER SA IND E COMÉRCIO, CVM: 002038
# Processo: 150/770, Processando empresa: BUNGE ALIMENTOS SA, CVM: 002593
# Processo: 151/770, Processando empresa: BUNGE BRASIL SA, CVM: 010278
# Processo: 152/770, Processando empresa: BUNGE FERTILIZANTES SA, CVM: 008370
# Processo: 153/770, Processando empresa: CABINDA PARTICIPAÇÕES SA, CVM: 019119
# Processo: 154/770, Processando empresa: CENTRAIS ELÉTRICAS CACHOEIRA DOURADA S/A, CVM: 016322
# Processo: 155/770, Processando empresa: CIA CACIQUE CAFE SOLUVEL, CVM: 002909
# Processo: 156/770, Processando empresa: CACONDE PARTICIPAÇÕES SA, CVM: 019135
# Processo: 157/770, Processando empresa: CAEMI MINERAÇÃO E METALURGIA S.A., CVM: 013552
# Processo: 158/770, Processando empresa: CAFE SOLUVEL BRASILIA SA, CVM: 002062
# Processo: 159/770, Processando empresa: CAIANDA PARTICIPAÇÕES SA, CVM: 019097
# Processo: 160/770, Processando empresa: CAIXA SEGURIDADE PARTICIPAÇÕES S.A., CVM: 023795
# Processo: 161/770, Processando empresa: CAMBUCI SA, CVM: 002100
# Processo: 162/770, Processando empresa: CAMIL ALIMENTOS S/A, CVM: 024228
# Processo: 163/770, Processando empresa: CAPITALPART PARTICIPAÇÕES SA, CVM: 017493
# Processo: 164/770, Processando empresa: CARGILL FERTILIZANTES SA, CVM: 010863
# Processo: 165/770, Processando empresa: ATACADÃO S.A., CVM: 024171
# Processo: 166/770, Processando empresa: CASA ANGLO BRASILEIRA S/A, CVM: 002178
# Processo: 167/770, Processando empresa: CIA CAT. DE ÁGUAS E SANEAMENTO - CASAN, CVM: 016861
# Processo: 168/770, Processando empresa: VIA S.A., CVM: 006505
# Processo: 169/770, Processando empresa: COMPANHIA BRASILEIRA DE ALUMINIO, CVM: 025984
# Processo: 170/770, Processando empresa: COMPANHIA BRASILEIRA DE CARTUCHOS - CBC, CVM: 013315
# Processo: 171/770, Processando empresa: CBCC PARTICIPAÇÕES SA, CVM: 017728
# Processo: 172/770, Processando empresa: CAMARGO CORREA DESENVOLVIMENTO  IMOBILIARIO SA, CVM: 020486
# Processo: 173/770, Processando empresa: CCR S.A., CVM: 018821
# Processo: 174/770, Processando empresa: CCX CARVÃO DA COLOMBIA S.A. - EM LIQUIDAÇÃO, CVM: 020184
# Processo: 175/770, Processando empresa: C&A MODAS S.A., CVM: 024848
# Processo: 176/770, Processando empresa: COMPANHIA ENERGÉTICA DE BRASÍLIA - CEB, CVM: 014451
# Processo: 177/770, Processando empresa: COMPANHIA DE FIACAO E TECIDOS CEDRO E CACHOEIRA, CVM: 003077
# Processo: 178/770, Processando empresa: CIA ESTADUAL DE DISTRIBUIÇÃO DE ENERGIA ELETRICA, CVM: 020648
# Processo: 179/770, Processando empresa: COMPANHIA ESTADUAL DE GERAÇÃO DE ENERGIA ELÉTRICA - CEEE-G, CVM: 027154
# Processo: 180/770, Processando empresa: CIA ESTADUAL DE GERACAO E TRANSMISSAO DE ENERGIA ELETRICA, CVM: 003204
# Processo: 181/770, Processando empresa: CIA. DISTRIB. DE GÁS DO RIO DE JANEIRO, CVM: 016616
# Processo: 182/770, Processando empresa: CENTRAIS ELETRICAS DE SANTA CATARINA S.A, CVM: 002461
# Processo: 183/770, Processando empresa: EQUATORIAL GOIAS DISTRIBUIDORA DE ENERGIA S.A., CVM: 025577
# Processo: 184/770, Processando empresa: COMPANHIA CELG DE PARTICIPAÇÕES - CELGPAR, CVM: 021393
# Processo: 185/770, Processando empresa: CELM CIA EQUIP LABS MODERNOS, CVM: 002402
# Processo: 186/770, Processando empresa: CIA ENERGÉTICA DE PERNAMBUCO - CELPE, CVM: 014362
# Processo: 187/770, Processando empresa: CEMEPE INVESTIMENTOS SA, CVM: 013854
# Processo: 188/770, Processando empresa: CIA ENERG MINAS GERAIS - CEMIG, CVM: 002453
# Processo: 189/770, Processando empresa: CENTENNIAL ASSET PARTICIPAÇÕES AÇU SA, CVM: 021245
# Processo: 190/770, Processando empresa: CENTENNIAL ASSET PART. MINAS-RIO S/A, CVM: 020176
# Processo: 191/770, Processando empresa: CESP - COMPANHIA ENERGÉTICA DE SÃO PAULO, CVM: 002577
# Processo: 192/770, Processando empresa: CETERP-CENT TELEF RIB PRETO SA, CVM: 015288
# Processo: 193/770, Processando empresa: CETIP S.A. - MERCADOS ORGANIZADOS, CVM: 021792
# Processo: 194/770, Processando empresa: MASSA FALIDA DA SA IND E COMERCIO CHAPECO, CVM: 010243
# Processo: 195/770, Processando empresa: CERAMICA CHIARELLI SA - EM RECUPERAÇÃO JUDICIAL, CVM: 002488
# Processo: 196/770, Processando empresa: CIA HERING, CVM: 014761
# Processo: 197/770, Processando empresa: CIELO S.A. - INSTITUIÇÃO DE PAGAMENTO, CVM: 021733
# Processo: 198/770, Processando empresa: COMPANHIA CIMENTO PORTLAND ITAU, CVM: 002933
# Processo: 199/770, Processando empresa: CIA INDL MERC ARTEF FERRO, CVM: 003468
# Processo: 200/770, Processando empresa: CIMOB PARTICIPAÇÕES SA, CVM: 006513
# Processo: 201/770, Processando empresa: CIMS SA, CVM: 014818
# Processo: 202/770, Processando empresa: CINESYSTEM S.A., CVM: 023965
# Processo: 203/770, Processando empresa: CLARION S/A AGROINDUSTRIAL, CVM: 513806
# Processo: 204/770, Processando empresa: CLEAR SALE S.A, CVM: 026093
# Processo: 205/770, Processando empresa: CMA PARTICIPAÇÕES SA, CVM: 013323
# Processo: 206/770, Processando empresa: COARI PARTICIPAÇÕES SA, CVM: 019089
# Processo: 207/770, Processando empresa: COBRASMA SA, CVM: 004448
# Processo: 208/770, Processando empresa: CIA DE ELETRICIDADE DO ESTADO DA BAHIA - COELBA, CVM: 014524
# Processo: 209/770, Processando empresa: CIA ENERG CEARA - COELCE, CVM: 014869
# Processo: 210/770, Processando empresa: COFAP CIA FABRICADORA PECAS, CVM: 004480
# Processo: 211/770, Processando empresa: COGNA EDUCAÇÃO S.A., CVM: 017973
# Processo: 212/770, Processando empresa: COINVEST CIA. DE INV. INTERLAGOS, CVM: 007552
# Processo: 213/770, Processando empresa: COLDEX FRIGOR SA, CVM: 012459
# Processo: 214/770, Processando empresa: COMERC PARTICIPAÇÕES S.A., CVM: 026280
# Processo: 215/770, Processando empresa: COMPANHIA DE GÁS DE SÃO PAULO - COMGÁS, CVM: 015636
# Processo: 216/770, Processando empresa: BROOKFIELD SÃO PAULO EMPREENDIMENTOS IMOBILIÁRIOS S.A., CVM: 019046
# Processo: 217/770, Processando empresa: COMPASS GÁS E ENERGIA S.A., CVM: 025127
# Processo: 218/770, Processando empresa: CONCESSIONARIA RIO-TERESOPOLIS SA, CVM: 019208
# Processo: 219/770, Processando empresa: CONFAB INDUSTRIAL SA, CVM: 004650
# Processo: 220/770, Processando empresa: CONSTRUTORA ADOLPHO LINDENBERG S.A., CVM: 004723
# Processo: 221/770, Processando empresa: CONSTRUTORA BETER SA, CVM: 004758
# Processo: 222/770, Processando empresa: BS CONTINENTAL SA ULTL DOMEST, CVM: 006327
# Processo: 223/770, Processando empresa: CIA PAULISTA FERTILIZANTES, CVM: 003816
# Processo: 224/770, Processando empresa: COMPANHIA DE SANEAMENTO DE MINAS GERAIS, CVM: 019445
# Processo: 225/770, Processando empresa: COMPANHIA PARANAENSE DE ENERGIA COPEL, CVM: 014311
# Processo: 226/770, Processando empresa: COPESUL - COMPANHIA PETROQUÍMICA DO SUL, CVM: 014044
# Processo: 227/770, Processando empresa: CORRÊA RIBEIRO S/A COMÉRCIO E INDÚSTRIA, CVM: 004863
# Processo: 228/770, Processando empresa: CORBETTA SA IND COM, CVM: 004839
# Processo: 229/770, Processando empresa: COSAN S.A., CVM: 019836
# Processo: 230/770, Processando empresa: COSAN LOGÍSTICA S.A., CVM: 023485
# Processo: 231/770, Processando empresa: CIA ENERGÉTICA DO RIO GRANDE DO NORTE, CVM: 018139
# Processo: 232/770, Processando empresa: COMPANHIA SIDERÚRGICA PAULISTA - COSIPA, CVM: 018317
# Processo: 233/770, Processando empresa: CIA TECIDOS NORTE DE MINAS - COTEMINAS, CVM: 003158
# Processo: 234/770, Processando empresa: CPFL ENERGIA SA, CVM: 018660
# Processo: 235/770, Processando empresa: CPFL GERAÇÃO DE ENERGIA S/A, CVM: 018953
# Processo: 236/770, Processando empresa: CIA PIRATININGA DE FORÇA E LUZ, CVM: 019275
# Processo: 237/770, Processando empresa: CPFL ENERGIAS RENOVÁVEIS S.A., CVM: 020540
# Processo: 238/770, Processando empresa: CREMER SA, CVM: 020141
# Processo: 239/770, Processando empresa: TRONOX PIGMENTOS DO BRASIL S.A., CVM: 011398
# Processo: 240/770, Processando empresa: CIA RIOGRANDENSE TELECOMUNICAÇÕES, CVM: 003913
# Processo: 241/770, Processando empresa: CRUZEIRO DO SUL EDUCACIONAL S.A., CVM: 025526
# Processo: 242/770, Processando empresa: MASSA FALIDA DO BANCO CRUZEIRO DO SUL S/A, CVM: 020753
# Processo: 243/770, Processando empresa: CSN MINERAÇÃO S.A., CVM: 025585
# Processo: 244/770, Processando empresa: CSU DIGITAL S.A., CVM: 020044
# Processo: 245/770, Processando empresa: CTC - CENTRO DE TECNOLOGIA CANAVIEIRA S.A., CVM: 023981
# Processo: 246/770, Processando empresa: CURY CONSTRUTORA E INCORPORADORA S.A., CVM: 025100
# Processo: 247/770, Processando empresa: CVC BRASIL OPERADORA E AGÊNCIA DE VIAGENS SA, CVM: 023310
# Processo: 248/770, Processando empresa: CYRELA BRAZIL REALTY S.A.EMPREEND E PART, CVM: 014460
# Processo: 249/770, Processando empresa: CZARINA SA, CVM: 012742
# Processo: 250/770, Processando empresa: D F VASCONC SA OPT MEC A PREC, CVM: 005029
# Processo: 251/770, Processando empresa: D1000 VAREJO FARMA PARTICIPAÇÕES S.A., CVM: 025046
# Processo: 252/770, Processando empresa: DALETH PARTICIPAÇÕES SA - EM LIQUIDAÇÃO, CVM: 016950
# Processo: 253/770, Processando empresa: DIAGNOSTICOS DA AMERICA SA, CVM: 019623
# Processo: 254/770, Processando empresa: DATASUL S/A, CVM: 020095
# Processo: 255/770, Processando empresa: BANCO DAYCOVAL S.A., CVM: 020796
# Processo: 256/770, Processando empresa: DESKTOP S.A, CVM: 026026
# Processo: 257/770, Processando empresa: DEXCO S.A., CVM: 021091
# Processo: 258/770, Processando empresa: DEXXOS PARTICIPAÇÕES S.A., CVM: 016632
# Processo: 259/770, Processando empresa: DHB IND E COMERCIO SA, CVM: 005150
# Processo: 260/770, Processando empresa: DIJON SA, CVM: 013838
# Processo: 261/770, Processando empresa: DIMED SA DISTRIBUIDORA DE MEDICAMENTOS, CVM: 009342
# Processo: 262/770, Processando empresa: DINAMICA ENERGIA S/A, CVM: 020052
# Processo: 263/770, Processando empresa: DIRECIONAL ENGENHARIA SA, CVM: 021350
# Processo: 264/770, Processando empresa: DIXIE TOGA SA, CVM: 014931
# Processo: 265/770, Processando empresa: DM FINANCEIRA S.A. - CRÉDITO, FINANCIAMENTO E INVESTIMENTO, CVM: 006076
# Processo: 266/770, Processando empresa: CIA DOCAS DE IMBITUBA, CVM: 003174
# Processo: 267/770, Processando empresa: DOCAS INVESTIMENTOS SA, CVM: 003182
# Processo: 268/770, Processando empresa: DOHLER S.A., CVM: 005207
# Processo: 269/770, Processando empresa: DOMMO ENERGIA S.A., CVM: 023493
# Processo: 270/770, Processando empresa: DOMMO EMPREENDIMENTOS IMOBILIÁRIOS S.A., CVM: 019070
# Processo: 271/770, Processando empresa: MCM CIMENTOS S.A., CVM: 022284
# Processo: 272/770, Processando empresa: DOTZ S.A., CVM: 025836
# Processo: 273/770, Processando empresa: DOUAT CIA TEXTIL, CVM: 011363
# Processo: 274/770, Processando empresa: DTCOM - DIRECT TO COMPANY S.A., CVM: 018597
# Processo: 275/770, Processando empresa: ECISA ENG COM E INDUSTRIA SA, CVM: 005339
# Processo: 276/770, Processando empresa: BANCO BESA SA, CVM: 001244
# Processo: 277/770, Processando empresa: ECORODOVIAS INFRAESTRUTURA E LOGÍSTICA S.A., CVM: 019453
# Processo: 278/770, Processando empresa: EDN ESTIRENO DO NORDESTE SA, CVM: 005363
# Processo: 279/770, Processando empresa: COMPANHIA  ELDORADO DE HOTEIS, CVM: 002763
# Processo: 280/770, Processando empresa: ELECTROLUX DO BRASIL SA, CVM: 010006
# Processo: 281/770, Processando empresa: ELEKEIROZ S/A, CVM: 004359
# Processo: 282/770, Processando empresa: ELEKTRO REDES S.A., CVM: 017485
# Processo: 283/770, Processando empresa: CENTRAIS ELETRICAS BRASILEIRAS SA, CVM: 002437
# Processo: 284/770, Processando empresa: ELETROMIDIA S.A., CVM: 025569
# Processo: 285/770, Processando empresa: ELETRON SA, CVM: 016209
# Processo: 286/770, Processando empresa: ELETROBRÁS PARTICIPAÇÕES S.A. - ELETROPAR, CVM: 015784
# Processo: 287/770, Processando empresa: ELETROPAULO METROP. ELET. SAO PAULO S.A., CVM: 014176
# Processo: 288/770, Processando empresa: ELEVA ALIMENTOS S/A, CVM: 012238
# Processo: 289/770, Processando empresa: ELEVADORES ATLAS SCHINDLER SA, CVM: 015598
# Processo: 290/770, Processando empresa: EMAE - EMPRESA METROP.AGUAS ENERGIA S.A., CVM: 016993
# Processo: 291/770, Processando empresa: EMBPAR PARTICIPAÇÕES S/A, CVM: 015458
# Processo: 292/770, Processando empresa: EMBRAER S.A., CVM: 020087
# Processo: 293/770, Processando empresa: EMBRATEL PARTICIPAÇÕES SA, CVM: 017647
# Processo: 294/770, Processando empresa: ENAUTA PARTICIPAÇÕES S.A., CVM: 022365
# Processo: 295/770, Processando empresa: EMP.NAC. DE COMÉRCIO, RÉDITO E PART. S.A. - ENCORPAR, CVM: 016497
# Processo: 296/770, Processando empresa: EDP ENERGIAS DO BRASIL S/A, CVM: 019763
# Processo: 297/770, Processando empresa: ENERGISA SA, CVM: 015253
# Processo: 298/770, Processando empresa: ENERGISA MATO GROSSO-DISTRIBUIDORA DE ENERGIA S/A, CVM: 014605
# Processo: 299/770, Processando empresa: ENERGISA MATO GROSSO DO SUL - DIST DE ENERGIA S.A., CVM: 005576
# Processo: 300/770, Processando empresa: ENEVA S.A., CVM: 021237
# Processo: 301/770, Processando empresa: ENGIE BRASIL ENERGIA S.A., CVM: 017329
# Processo: 302/770, Processando empresa: ENJOEI S.A., CVM: 025259
# Processo: 303/770, Processando empresa: ENXUTA SA, CVM: 012211
# Processo: 304/770, Processando empresa: EQUATORIAL MARANHÃO DISTRIBUIDORA DE ENERGIA S.A., CVM: 016608
# Processo: 305/770, Processando empresa: EQUATORIAL PARÁ DISTRIBUIDORA DE ENERGIA S.A., CVM: 018309
# Processo: 306/770, Processando empresa: EQUATORIAL ENERGIA S/A, CVM: 020010
# Processo: 307/770, Processando empresa: ERICSSON TELECOMUNICACOES SA, CVM: 005690
# Processo: 308/770, Processando empresa: EDP ESPIRITO SANTO DISTRIBUIÇÃO DE ENERGIA S.A., CVM: 015342
# Processo: 309/770, Processando empresa: MPM CORPÓREOS S.A., CVM: 025445
# Processo: 310/770, Processando empresa: ALLPARK EMPREENDIMENTOS, PARTICIPAÇÕES E SERVIÇOS S.A., CVM: 024953
# Processo: 311/770, Processando empresa: MANUFATURA DE  BRINQUEDOS ESTRELA SA, CVM: 008427
# Processo: 312/770, Processando empresa: ETERNIT S.A.- EM RECUPERAÇÃO JUDICIAL, CVM: 005762
# Processo: 313/770, Processando empresa: EUCATEX S.A. INDUSTRIA E COMERCIO, CVM: 005770
# Processo: 314/770, Processando empresa: EUROFARMA LABORATÓRIOS S.A., CVM: 026700
# Processo: 315/770, Processando empresa: EVEN CONSTRUTORA E INCORPORADORA S/A, CVM: 020524
# Processo: 316/770, Processando empresa: EXCELSIOR ALIMENTOS SA., CVM: 001570
# Processo: 317/770, Processando empresa: EZ TEC EMPREEND. E PARTICIPAÇÕES S/A, CVM: 020770
# Processo: 318/770, Processando empresa: ENERGISA MINAS RIO - DISTRIBUIDORA DE ENERGIA S/A, CVM: 003271
# Processo: 319/770, Processando empresa: MASSA FALIDA DE COMPANHIA TEXTIL FERREIRA GUIMARAES, CVM: 004138
# Processo: 320/770, Processando empresa: MASSA FALIDA DA FÁBRICA DE TECIDOS CARLOS RENAUX S.A., CVM: 005827
# Processo: 321/770, Processando empresa: FERRAGENS DEMELLOT S/A, CVM: 005924
# Processo: 322/770, Processando empresa: FERTILIZANTES HERINGER S.A., CVM: 020621
# Processo: 323/770, Processando empresa: CIA FERRO LIGAS BAHIA FERBASA, CVM: 003069
# Processo: 324/770, Processando empresa: COMPANHIA PAULISTA FERRO LIGAS, CVM: 003808
# Processo: 325/770, Processando empresa: FERTIBRAS SA, CVM: 005940
# Processo: 326/770, Processando empresa: FIBAM CIA INDUSTRIAL - EM RECUPERAÇÃO JUDICIAL, CVM: 006017
# Processo: 327/770, Processando empresa: FIBRIA CELULOSE S.A., CVM: 012793
# Processo: 328/770, Processando empresa: FICA EMPREENDIMENTOS IMOBILIARIOS S.A., CVM: 020630
# Processo: 329/770, Processando empresa: FLEURY SA, CVM: 021881
# Processo: 330/770, Processando empresa: FLEX GESTAO DE RELACIONAMENTOS SA EM RECUPERACAO JUDICIAL, CVM: 024350
# Processo: 331/770, Processando empresa: COMPANHIA FLUMINENSE DE REFRIGERANTES, CVM: 003263
# Processo: 332/770, Processando empresa: FOCUS ENERGIA HOLDING PARTICIPAÇÕES S.A., CVM: 025488
# Processo: 333/770, Processando empresa: FORNO DE MINAS ALIMENTOS S.A., CVM: 023736
# Processo: 334/770, Processando empresa: FRANGOSUL SA AGRO AVICOLA INDL, CVM: 011967
# Processo: 335/770, Processando empresa: FRAS-LE SA, CVM: 006211
# Processo: 336/770, Processando empresa: FUTURETEL S.A. - EM LIQUIDAÇÃO, CVM: 017388
# Processo: 337/770, Processando empresa: GAFISA SA, CVM: 016101
# Processo: 338/770, Processando empresa: GAMA PARTICIPAÇÕES S.A., CVM: 017965
# Processo: 339/770, Processando empresa: GAZOLA SA INDÚSTRIA METALURGICA, CVM: 006378
# Processo: 340/770, Processando empresa: GENERAL SHOPPING E OUTLETS DO BRASIL BRASIL S.A., CVM: 021008
# Processo: 341/770, Processando empresa: GEODEX COMMUNICATIONS S.A., CVM: 018031
# Processo: 342/770, Processando empresa: RIO PARANAPANEMA ENERGIA SA, CVM: 018368
# Processo: 343/770, Processando empresa: GERAL DE CONCRETO S/A, CVM: 005630
# Processo: 344/770, Processando empresa: GERDAU S.A., CVM: 003980
# Processo: 345/770, Processando empresa: METALURGICA GERDAU SA, CVM: 008656
# Processo: 346/770, Processando empresa: GETNET ADQUIRÊNCIA E SERVIÇOS PARA MEIOS DE PAGAMENTO S.A., CVM: 026140
# Processo: 347/770, Processando empresa: GETNINJAS S.A., CVM: 025887
# Processo: 348/770, Processando empresa: GLASSLITE SA IND DE PLASTICOS, CVM: 006483
# Processo: 349/770, Processando empresa: GOL LINHAS AEREAS INTELIGENTES SA, CVM: 019569
# Processo: 350/770, Processando empresa: GPS PARTICIPAÇÕES E EMPREENDIMENTOS S/A, CVM: 025712
# Processo: 351/770, Processando empresa: GRANOLEO SA CI SEMS OLEAGS DER, CVM: 006572
# Processo: 352/770, Processando empresa: GRAZZIOTIN SA, CVM: 004537
# Processo: 353/770, Processando empresa: GRENDENE SA, CVM: 019615
# Processo: 354/770, Processando empresa: GRUÇAI PARTICIPAÇÕES SA, CVM: 015695
# Processo: 355/770, Processando empresa: GRUPO MATEUS S.A., CVM: 025186
# Processo: 356/770, Processando empresa: NATURA & CO HOLDING S.A., CVM: 024783
# Processo: 357/770, Processando empresa: GRUPO SBF S.A., CVM: 024694
# Processo: 358/770, Processando empresa: GRUPO DE MODA SOMA S.A., CVM: 025011
# Processo: 359/770, Processando empresa: GTD PARTICIPACOES SA, CVM: 014915
# Processo: 360/770, Processando empresa: AÇUCAR GUARANI S/A, CVM: 020940
# Processo: 361/770, Processando empresa: GUARARAPES CONFECÇÕES SA, CVM: 004669
# Processo: 362/770, Processando empresa: GVT HOLDING S/A, CVM: 020117
# Processo: 363/770, Processando empresa: COMPANHIIA HABITASUL DE PARTICIPAÇÕES, CVM: 003298
# Processo: 364/770, Processando empresa: HAGA S.A. INDÚSTRIA E COMÉRCIO, CVM: 013366
# Processo: 365/770, Processando empresa: HAPVIDA PARTICIPAÇÕES E INVESTIMENTOS S.A., CVM: 024392
# Processo: 366/770, Processando empresa: HARPIA ÔMEGA PARTICIPAÇÕES S.A., CVM: 022578
# Processo: 367/770, Processando empresa: HBR REALTY EMPREENDIMENTOS IMOBILIÁRIOS S.A., CVM: 025402
# Processo: 368/770, Processando empresa: HELBOR EMPREENDIMENTOS S/A, CVM: 020877
# Processo: 369/770, Processando empresa: HERCULES S/A - FABRICA DE TALHERES, CVM: 006629
# Processo: 370/770, Processando empresa: HIDROVIAS DO BRASIL S.A., CVM: 022675
# Processo: 371/770, Processando empresa: HMOBI PARTICIPAÇÕES S.A, CVM: 025674
# Processo: 372/770, Processando empresa: HOTEIS OTHON S.A. - EM RECUPERAÇÃO JUDICIAL, CVM: 006700
# Processo: 373/770, Processando empresa: HSBC SEGUROS BRASIL SA, CVM: 000728
# Processo: 374/770, Processando empresa: HYPERA S/A, CVM: 021431
# Processo: 375/770, Processando empresa: INEPAR ENERGIA SA, CVM: 016730
# Processo: 376/770, Processando empresa: IGB ELETRÔNICA S.A. - EM RECUPERAÇÃO JUDICIAL, CVM: 006815
# Processo: 377/770, Processando empresa: IGUA SANEAMENTO S.A., CVM: 023175
# Processo: 378/770, Processando empresa: CIA. IGUAÇU DE CAFÉ SOLÚVEL, CVM: 003336
# Processo: 379/770, Processando empresa: IGUATEMI EMPRESA DE SHOPPING CENTERS S/A, CVM: 020494
# Processo: 380/770, Processando empresa: IGUATEMI S.A., CVM: 008672
# Processo: 381/770, Processando empresa: INSTITUTO HERMES PARDINI S/A, CVM: 024090
# Processo: 382/770, Processando empresa: INTERNATIONAL MEAL COMPANY HOLDINGS, SA, CVM: 022438
# Processo: 383/770, Processando empresa: INTERNATIONAL MEAL COMPANY ALIMENTAÇÃO S.A., CVM: 023574
# Processo: 384/770, Processando empresa: IMPERIO LISAMAR SA IND E COM, CVM: 014567
# Processo: 385/770, Processando empresa: INBRAC SA CONDUTORES ELETRICOS, CVM: 006874
# Processo: 386/770, Processando empresa: COMPANHIA INDUSTRIAL CATAGUASES, CVM: 003395
# Processo: 387/770, Processando empresa: BANCO VOITER S.A., CVM: 020885
# Processo: 388/770, Processando empresa: INEPAR S.A. INDUSTRIA E CONSTRUCOES EM RECUPERACAO JUDICIAL, CVM: 007595
# Processo: 389/770, Processando empresa: INFRACOMMERCE CXAAS S.A., CVM: 025747
# Processo: 390/770, Processando empresa: INTELBRAS S.A. IND. DE TELECOMUNICAÇÃO ELETRÔNICA BRASILEIRA, CVM: 025453
# Processo: 391/770, Processando empresa: INTER CONSTRUTORA E INCORPORADORA S.A, CVM: 024279
# Processo: 392/770, Processando empresa: NOTRE DAME INTERMÉDICA PARTICIPAÇÕES S.A., CVM: 024384
# Processo: 393/770, Processando empresa: INVESTIMENTOS E PARTICIP EM INFRA SA INVEPAR, CVM: 018775
# Processo: 394/770, Processando empresa: INVESTIMENTOS BEMGE S.A., CVM: 006041
# Processo: 395/770, Processando empresa: IOCHPE MAXION SA, CVM: 011932
# Processo: 396/770, Processando empresa: DISTRIB PRODUTOS PETROLEO IPIRANGA S.A., CVM: 005193
# Processo: 397/770, Processando empresa: CIA. BRAS PETRÓLEO IPIRANGA, CVM: 002860
# Processo: 398/770, Processando empresa: REFINARIA PET IPIRANGA SA, CVM: 009997
# Processo: 399/770, Processando empresa: IRANI PAPEL E EMBALAGEM S.A., CVM: 002429
# Processo: 400/770, Processando empresa: IRB - BRASIL RESSEGUROS S.A., CVM: 024180
# Processo: 401/770, Processando empresa: ITAITINGA PARTICIPACOES SA, CVM: 015865
# Processo: 402/770, Processando empresa: ITAUSA S.A., CVM: 007617
# Processo: 403/770, Processando empresa: ITAUTEC S.A. - GRUPO ITAUTEC, CVM: 012530
# Processo: 404/770, Processando empresa: ITAÚ UNIBANCO HOLDING S.A., CVM: 019348
# Processo: 405/770, Processando empresa: INDÚSTRIA VEROLME S.A. - IVESA, CVM: 012866
# Processo: 406/770, Processando empresa: JALLES MACHADO S.A., CVM: 025496
# Processo: 407/770, Processando empresa: JARAGUA FABRIL SA, CVM: 007781
# Processo: 408/770, Processando empresa: JBS SA, CVM: 020575
# Processo: 409/770, Processando empresa: JHSF PARTICIPAÇÕES SA, CVM: 020605
# Processo: 410/770, Processando empresa: JOAO FORTES ENGENHARIA SA - EM RECUPERAÇÃO JUDICIAL, CVM: 007811
# Processo: 411/770, Processando empresa: JOSAPAR-JOAQUIM OLIVEIRA S.A. - PARTICIP, CVM: 013285
# Processo: 412/770, Processando empresa: JSL S.A., CVM: 022020
# Processo: 413/770, Processando empresa: KALLAS INCORPORAÇÕES E CONSTRUÇÕES S.A., CVM: 025798
# Processo: 414/770, Processando empresa: KARSTEN SA, CVM: 004146
# Processo: 415/770, Processando empresa: KEPLER WEBER SA, CVM: 007870
# Processo: 416/770, Processando empresa: KLABIN S.A., CVM: 012653
# Processo: 417/770, Processando empresa: KLABIN SEGALL S/A, CVM: 020249
# Processo: 418/770, Processando empresa: KORA SAÚDE PARTICIPAÇÕES S.A., CVM: 025879
# Processo: 419/770, Processando empresa: KUALA SA, CVM: 000566
# Processo: 420/770, Processando empresa: JPSP INVESTIMENTOS E PARTICIPAÇÕES S.A., CVM: 012262
# Processo: 421/770, Processando empresa: LARK SA MAQ E EQUIPAMENTOS(Massa Falida Administrada Judicialmente p/Soc.Advogados Mandel Advocacia), CVM: 007978
# Processo: 422/770, Processando empresa: LAVVI EMPREENDIMENTOS IMOBILIÁRIOS S.A, CVM: 025062
# Processo: 423/770, Processando empresa: CVLB BRASIL S.A., CVM: 025542
# Processo: 424/770, Processando empresa: CIA LECO DE PRODS ALIMENTICIOS, CVM: 003603
# Processo: 425/770, Processando empresa: LF TEL SA, CVM: 017442
# Processo: 426/770, Processando empresa: JP PARTICIPAÇÕES S.A., CVM: 023299
# Processo: 427/770, Processando empresa: LIGAS DE ALUMINIO SA LIASA, CVM: 008028
# Processo: 428/770, Processando empresa: LIFEMED INDUSTRIAL DE EQUIP. E ART. MEDICOS E HOSP. S.A., CVM: 024872
# Processo: 429/770, Processando empresa: LIGHT S.A. - EM RECUPERAÇÃO JUDICIAL, CVM: 019879
# Processo: 430/770, Processando empresa: CIRCULO S/A, CVM: 007056
# Processo: 431/770, Processando empresa: LINX S.A., CVM: 023035
# Processo: 432/770, Processando empresa: LITEL PARTICIPACOES SA, CVM: 015091
# Processo: 433/770, Processando empresa: LITELA PARTICIPAÇÕES S.A. - EM LIQUIDAÇÃO, CVM: 024759
# Processo: 434/770, Processando empresa: LIVRARIA DO GLOBO SA, CVM: 008060
# Processo: 435/770, Processando empresa: CONST LIX DA CUNHA SA, CVM: 004774
# Processo: 436/770, Processando empresa: LOCALIZA RENT A CAR SA, CVM: 019739
# Processo: 437/770, Processando empresa: COMPANHIA DE LOCAÇÃO DAS AMERICAS, CVM: 022691
# Processo: 438/770, Processando empresa: LOCAWEB SERVIÇOS DE INTERNET S.A., CVM: 024910
# Processo: 439/770, Processando empresa: LOG COMMERCIAL PROPERTIES E PARTICIPAÇÕES, CVM: 023272
# Processo: 440/770, Processando empresa: LOG-IN LOGISTICA INTERMODAL SA, CVM: 020710
# Processo: 441/770, Processando empresa: LOJAS AMERICANAS SA, CVM: 008087
# Processo: 442/770, Processando empresa: KOSMOS COMÉRCIO DE VESTUÁRIO S/A - EM RECUPERAÇÃO JUDICIAL, CVM: 015083
# Processo: 443/770, Processando empresa: LOJAS HERING SA, CVM: 008117
# Processo: 444/770, Processando empresa: MARISA LOJAS SA, CVM: 022055
# Processo: 445/770, Processando empresa: LOJAS RENNER SA, CVM: 008133
# Processo: 446/770, Processando empresa: LONGDIS SA, CVM: 017434
# Processo: 447/770, Processando empresa: LPS BRASIL CONSULTORIA DE IMOVEIS S/A, CVM: 020370
# Processo: 448/770, Processando empresa: MASSA FALIDA DA CIA LORENZ, CVM: 003611
# Processo: 449/770, Processando empresa: LUPATECH S/A - EM RECUPERAÇÃO JUDICIAL, CVM: 020060
# Processo: 450/770, Processando empresa: M&G POLIÉSTER SA, CVM: 505820
# Processo: 451/770, Processando empresa: M. DIAS BRANCO SA IND E COM DE ALIMENTOS, CVM: 020338
# Processo: 452/770, Processando empresa: INDS MADEIRIT SA, CVM: 007439
# Processo: 453/770, Processando empresa: MAESTRO LOCADORA DE VEÍCULOS S.A., CVM: 023612
# Processo: 454/770, Processando empresa: MAGAZINE LUIZA SA, CVM: 022470
# Processo: 455/770, Processando empresa: MAGNESITA REFRATARIOS S.A., CVM: 020842
# Processo: 456/770, Processando empresa: MAHLE COFAP ANEIS SA, CVM: 018520
# Processo: 457/770, Processando empresa: DE MAIO GALLO S.A IND. COM. PÇS P/ AUTOM, CVM: 005088
# Processo: 458/770, Processando empresa: MAKRO ATACADISTA SA, CVM: 014834
# Processo: 459/770, Processando empresa: MANASA MADEIREIRA NACIONAL SA, CVM: 008389
# Processo: 460/770, Processando empresa: MANGELS INDUSTRIAL S.A., CVM: 008397
# Processo: 461/770, Processando empresa: VALLOUREC & MANNESMANN TUBES - V & M DOBRASIL, CVM: 008400
# Processo: 462/770, Processando empresa: MAORI SA, CVM: 017779
# Processo: 463/770, Processando empresa: MARAMBAIA ENERGIA RENOVÁVEL SA, CVM: 012181
# Processo: 464/770, Processando empresa: MARCOPOLO SA, CVM: 008451
# Processo: 465/770, Processando empresa: MARFRIG GLOBAL FOODS SA, CVM: 020788
# Processo: 466/770, Processando empresa: MARISOL SA, CVM: 008486
# Processo: 467/770, Processando empresa: HOSPITAL MATER DEI S.A., CVM: 025690
# Processo: 468/770, Processando empresa: MCOM WIRELESS SA, CVM: 015504
# Processo: 469/770, Processando empresa: MEDIAL SAUDE S/A, CVM: 020273
# Processo: 470/770, Processando empresa: COMPANHIA  MELHORAMENTOS DE SÃO PAULO, CVM: 003654
# Processo: 471/770, Processando empresa: MELIUZ S.A., CVM: 025232
# Processo: 472/770, Processando empresa: MELNICK DESENVOLVIMENTO IMOBILIÁRIO S.A., CVM: 025119
# Processo: 473/770, Processando empresa: MELPAPER SA, CVM: 014532
# Processo: 474/770, Processando empresa: MENDES JUNIOR ENGENHARIA SA, CVM: 004782
# Processo: 475/770, Processando empresa: TERMINAL GARAGEM MENEZES CORTES SA, CVM: 018538
# Processo: 476/770, Processando empresa: CREDITAQUI FINANCEIRA S.A. CRÉDITO, FINANCIAMENTO E INVESTIMENTO, CVM: 008540
# Processo: 477/770, Processando empresa: BANCO MERCANTIL DE INVESTIMENTOS S.A., CVM: 001309
# Processo: 478/770, Processando empresa: BANCO MERCANTIL DE SÃO PAULO SA, CVM: 001317
# Processo: 479/770, Processando empresa: BANCO MERCANTIL BRASIL SA, CVM: 001325
# Processo: 480/770, Processando empresa: MESBLA SA, CVM: 008559
# Processo: 481/770, Processando empresa: METALURGICA DUQUE SA - EM RECUPERAÇÃO JUDICIAL, CVM: 008648
# Processo: 482/770, Processando empresa: METALGRAFICA IGUACU SA, CVM: 008605
# Processo: 483/770, Processando empresa: MAHLE METAL LEVE S.A., CVM: 008575
# Processo: 484/770, Processando empresa: METALFRIO SOLUTIONS S/A, CVM: 020613
# Processo: 485/770, Processando empresa: METISA METALÚRGICA  TIMBOENSE SA, CVM: 008753
# Processo: 486/770, Processando empresa: METODO ENGENHARIA SA, CVM: 017876
# Processo: 487/770, Processando empresa: INDUSTRIAS MICHELETTO S/A, CVM: 007447
# Processo: 488/770, Processando empresa: MILLS LOCAÇÃO, SERVIÇOS E LOGÍSTICA S.A., CVM: 022012
# Processo: 489/770, Processando empresa: MINASMAQUINAS SA, CVM: 008818
# Processo: 490/770, Processando empresa: MINERVA S/A, CVM: 020931
# Processo: 491/770, Processando empresa: MINUPAR PARTICIPACOES SA, CVM: 013765
# Processo: 492/770, Processando empresa: MITRE REALTY EMPREENDIMENTOS E PARTICIPAÇÕES S.A., CVM: 024902
# Processo: 493/770, Processando empresa: MMX MINERACAO E METALICOS SA FALIDA, CVM: 017914
# Processo: 494/770, Processando empresa: MOBLY S.A., CVM: 025461
# Processo: 495/770, Processando empresa: BANCO MODAL S.A., CVM: 025755
# Processo: 496/770, Processando empresa: MONTEIRO ARANHA SA, CVM: 008893
# Processo: 497/770, Processando empresa: MONTREAL EMPR COM E IND SA, CVM: 008907
# Processo: 498/770, Processando empresa: MOSAICO TECNOLOGIA AO CONSUMIDOR S.A., CVM: 025470
# Processo: 499/770, Processando empresa: MOURA DUBEUX ENGENHARIA S/A, CVM: 021067
# Processo: 500/770, Processando empresa: MOVIDA PARTICIPAÇÕES S.A., CVM: 023825
# Processo: 501/770, Processando empresa: MRS LOGÍSTICA S/A, CVM: 017949
# Processo: 502/770, Processando empresa: MRV ENGENHARIA E PARTICIPAÇÕES S/A, CVM: 020915
# Processo: 503/770, Processando empresa: MASSA FALIDA DA MULLER IND E COMERCIO, CVM: 008982
# Processo: 504/770, Processando empresa: MULTILASER INDUSTRIAL S.A., CVM: 026034
# Processo: 505/770, Processando empresa: MULTIPLAN - EMPREEND IMOBILIARIOS S.A., CVM: 020982
# Processo: 506/770, Processando empresa: MULTIPLUS SA, CVM: 021946
# Processo: 507/770, Processando empresa: MUNDIAL S.A - PRODUTOS DE CONSUMO, CVM: 005312
# Processo: 508/770, Processando empresa: BANCO NACIONAL S.A. - EM LIQUIDAÇÃO EXTRAJUDICIAL, CVM: 001350
# Processo: 509/770, Processando empresa: NADIR FIGUEIREDO S.A, CVM: 009040
# Processo: 510/770, Processando empresa: NAKATA SA IND E COMERCIO, CVM: 009059
# Processo: 511/770, Processando empresa: NEOENERGIA S.A, CVM: 015539
# Processo: 512/770, Processando empresa: NEOGRID PARTICIPACÕES S.A., CVM: 025399
# Processo: 513/770, Processando empresa: NET SERVIÇOS DE COMUNICAÇÃO S.A., CVM: 014621
# Processo: 514/770, Processando empresa: NEWTEL PARTICIPAÇÕES S.A. - EM LIQUIDAÇÃO, CVM: 017540
# Processo: 515/770, Processando empresa: NEXPE PARTICIPAÇÕES S.A., CVM: 021180
# Processo: 516/770, Processando empresa: BANCO DO NORDESTE DO BRASIL SA, CVM: 001228
# Processo: 517/770, Processando empresa: NORDON INDUSTRIAS METALURGICAS S.A., CVM: 009083
# Processo: 518/770, Processando empresa: NORTEC QUIMICA S.A., CVM: 022985
# Processo: 519/770, Processando empresa: NUTRIPLANT INDUSTRIA E COMÉRCIO S/A, CVM: 021334
# Processo: 520/770, Processando empresa: OCEANPACT SERVIÇOS MARÍTIMOS S.A., CVM: 025534
# Processo: 521/770, Processando empresa: ODEBRECHT SA, CVM: 009199
# Processo: 522/770, Processando empresa: CONSERVAS ODERICH SA, CVM: 004693
# Processo: 523/770, Processando empresa: ODONTOPREV S/A, CVM: 020125
# Processo: 524/770, Processando empresa: OI S.A. - EM RECUPERAÇÃO JUDICIAL, CVM: 011312
# Processo: 525/770, Processando empresa: MASSA FALIDA DE OLMA SA OLEOS VEGETAIS, CVM: 013560
# Processo: 526/770, Processando empresa: OLVEBRA SA, CVM: 009245
# Processo: 527/770, Processando empresa: OMEGA ENERGIA S.A., CVM: 026441
# Processo: 528/770, Processando empresa: ONCOCLÍNICAS DO BRASIL SERVIÇOS MÉDICOS S.A., CVM: 026123
# Processo: 529/770, Processando empresa: OPPORTUNITY ENERGIA E PARTICIPAÇÕES S.A., CVM: 016942
# Processo: 530/770, Processando empresa: ORION SA, CVM: 009261
# Processo: 531/770, Processando empresa: ORIZON VALORIZAÇÃO DE RESÍDUOS S.A., CVM: 025550
# Processo: 532/770, Processando empresa: OSX BRASIL S.A., CVM: 021342
# Processo: 533/770, Processando empresa: OURO FINO SAÚDE ANIMAL PARTICIPAÇÕES S.A., CVM: 023507
# Processo: 534/770, Processando empresa: OXITENO S.A. - INDÚSTRIA E COMÉRCIO, CVM: 013072
# Processo: 535/770, Processando empresa: COMPANHIA BRASILEIRA DE DISTRIBUIÇÃO, CVM: 014826
# Processo: 536/770, Processando empresa: PACIFIC RDSL PARTICIPAÇÕES S.A., CVM: 024163
# Processo: 537/770, Processando empresa: PADTEC HOLDING S.A., CVM: 018414
# Processo: 538/770, Processando empresa: EMPREENDIMENTOS PAGUE MENOS SA, CVM: 022608
# Processo: 539/770, Processando empresa: PANATLANTICA SA, CVM: 000094
# Processo: 540/770, Processando empresa: PANEX SA INDUSTRIA E COMERCIO, CVM: 015490
# Processo: 541/770, Processando empresa: CIA DE PARTICIPAÇÕES ALIANÇA DA BAHIA, CVM: 018708
# Processo: 542/770, Processando empresa: COMPANHIA PARAIBUNA DE METAIS, CVM: 012130
# Processo: 543/770, Processando empresa: PARANA BANCO S.A., CVM: 020729
# Processo: 544/770, Processando empresa: COMPANHIA PAULISTA DE FORCA LUZ - CPFL, CVM: 003824
# Processo: 545/770, Processando empresa: PDG REALTY S.A. EMPREEND E PARTICIPACOES, CVM: 020478
# Processo: 546/770, Processando empresa: PEIXE SA, CVM: 012092
# Processo: 547/770, Processando empresa: PERSICO PIZZAMIGLIO SA, CVM: 009490
# Processo: 548/770, Processando empresa: REFINARIA PET MANGUINHOS SA, CVM: 009989
# Processo: 549/770, Processando empresa: PETRÓLEO BRASILEIRO  S.A.  - PETROBRAS, CVM: 009512
# Processo: 550/770, Processando empresa: VIBRA ENERGIA S/A, CVM: 024295
# Processo: 551/770, Processando empresa: PETROFLEX INDÚSTRIA E COMÉRCIO S.A., CVM: 013994
# Processo: 552/770, Processando empresa: PETROQUIMICA UNIAO SA, CVM: 014494
# Processo: 553/770, Processando empresa: PETROBRAS QUÍMICA S.A.- PETROQUISA, CVM: 013595
# Processo: 554/770, Processando empresa: PETRORECÔNCAVO S.A., CVM: 025780
# Processo: 555/770, Processando empresa: PRIO S.A., CVM: 022187
# Processo: 556/770, Processando empresa: PETTENATI S.A. INDUSTRIA TEXTIL, CVM: 009539
# Processo: 557/770, Processando empresa: PET CENTER COMÉRCIO E PARTICIPAÇÕES S.A., CVM: 025089
# Processo: 558/770, Processando empresa: BANCO PINE S/A, CVM: 020567
# Processo: 559/770, Processando empresa: PIRELLI CABOS SA, CVM: 009601
# Processo: 560/770, Processando empresa: PIRELLI PNEUS SA, CVM: 013358
# Processo: 561/770, Processando empresa: PLANO & PLANO DESENVOLVIMENTO IMOBILIÁRIO S.A., CVM: 025070
# Processo: 562/770, Processando empresa: PLASCAR PARTICIPAÇÕES INDUSTRIAIS S.A, CVM: 013471
# Processo: 563/770, Processando empresa: IND BEBS ANTARCTICA POLAR SA, CVM: 007005
# Processo: 564/770, Processando empresa: POLIPROPILENO PARTICIPACOES S.A., CVM: 015997
# Processo: 565/770, Processando empresa: POLPAR S.A., CVM: 013447
# Processo: 566/770, Processando empresa: POMIFRUTAS S/A - EM RECUPERAÇÃO JUDICIAL, CVM: 019658
# Processo: 567/770, Processando empresa: PORTO SEGURO SA, CVM: 016659
# Processo: 568/770, Processando empresa: PBG S/A, CVM: 013773
# Processo: 569/770, Processando empresa: PORTX OPERAÇÕES PORTUÁRIAS S.A., CVM: 021776
# Processo: 570/770, Processando empresa: POSITIVO TECNOLOGIA S.A., CVM: 020362
# Processo: 571/770, Processando empresa: HOPI HARI SA, CVM: 015377
# Processo: 572/770, Processando empresa: PRÁTICA PARTICIPAÇÕES S.A., CVM: 023728
# Processo: 573/770, Processando empresa: PRÁTICA PRODUTOS S.A., CVM: 024546
# Processo: 574/770, Processando empresa: PRINER SERVIÇOS INDUSTRIAIS S.A., CVM: 024236
# Processo: 575/770, Processando empresa: PRÓ METALURGIA SA - EM LIQUIDAÇÃO EXTRAJUDICIAL, CVM: 001686
# Processo: 576/770, Processando empresa: PROFARMA DISTRIB PROD FARMACEUTICOS S.A., CVM: 020346
# Processo: 577/770, Processando empresa: BANCO DO PROGRESSO S.A., CVM: 001236
# Processo: 578/770, Processando empresa: PRODUTORES ENERGET.DE MANSO S.A.- PROMAN, CVM: 019232
# Processo: 579/770, Processando empresa: PROMPT PARTICIPAÇÕES S.A., CVM: 018333
# Processo: 580/770, Processando empresa: PRONOR PETROQUIMICA SA, CVM: 009784
# Processo: 581/770, Processando empresa: COMPANHIA PROVIDENCIA IND E COMERCIO, CVM: 020974
# Processo: 582/770, Processando empresa: PRUMO LOGÍSTICA S.A., CVM: 021482
# Processo: 583/770, Processando empresa: QUALICORP CONSULTORIA E CORRETORA DE SEGUROS S.A., CVM: 022497
# Processo: 584/770, Processando empresa: QUALITY SOFTWARE S.A., CVM: 023302
# Processo: 585/770, Processando empresa: QUATTOR PETROQUÍMICA S.A., CVM: 019267
# Processo: 586/770, Processando empresa: LOJAS QUERO QUERO S.A., CVM: 025038
# Processo: 587/770, Processando empresa: RAIA SA, CVM: 022306
# Processo: 588/770, Processando empresa: RAIA DROGASIL S.A., CVM: 005258
# Processo: 589/770, Processando empresa: RAÍZEN S.A., CVM: 025917
# Processo: 590/770, Processando empresa: RANDON S.A. IMPLEMENTOS E PARTICIPAÇÕES, CVM: 014109
# Processo: 591/770, Processando empresa: RASIP AGRO PASTORIL SA, CVM: 018279
# Processo: 592/770, Processando empresa: REAL CONSÓRCIO PART. S.A.(EM LIQUIDAÇÃO), CVM: 018023
# Processo: 593/770, Processando empresa: REAL HOLDINGS PART. S.A. (EM LIQUIDAÇÃO), CVM: 018007
# Processo: 594/770, Processando empresa: REALPAR PARTICIPAÇÕES S.A-EM LIQUIDAÇÃO, CVM: 018015
# Processo: 595/770, Processando empresa: RECRUSUL SA, CVM: 012572
# Processo: 596/770, Processando empresa: REDE D'OR SÃO LUIZ S.A., CVM: 024821
# Processo: 597/770, Processando empresa: REDE ENERGIA PARTICIPAÇÕES S.A., CVM: 003190
# Processo: 598/770, Processando empresa: REDECARD S/A, CVM: 020893
# Processo: 599/770, Processando empresa: REDENTOR ENERGIA S/A, CVM: 022128
# Processo: 600/770, Processando empresa: RENNER HERRMANN SA, CVM: 010030
# Processo: 601/770, Processando empresa: RENNER PARTICIPAÇÕES SA, CVM: 017752
# Processo: 602/770, Processando empresa: RENOVA ENERGIA S.A. -  EM RECUPERAÇÃO JUDICIAL, CVM: 021636
# Processo: 603/770, Processando empresa: RET PARTICIPAÇÕES S/A, CVM: 017337
# Processo: 604/770, Processando empresa: REXAM BEVERAGE CAN SOUTH AMERICA S.A., CVM: 016250
# Processo: 605/770, Processando empresa: RIMET EMPREEND. INDS. E COMERCIAIS S/A, CVM: 012840
# Processo: 606/770, Processando empresa: RIO GRANDE ENERGIA SA, CVM: 016535
# Processo: 607/770, Processando empresa: METALURGICA RIOSULENSE SA, CVM: 013439
# Processo: 608/770, Processando empresa: RJ CAPITAL PARTNERS S.A., CVM: 022330
# Processo: 609/770, Processando empresa: RNI NEGÓCIOS IMOBILIÁRIOS S.A., CVM: 020451
# Processo: 610/770, Processando empresa: RODOBENS S.A., CVM: 025801
# Processo: 611/770, Processando empresa: ROMI S.A., CVM: 007510
# Processo: 612/770, Processando empresa: ROSSI RESIDENCIAL S.A. - EM RECUPERAÇÃO JUDICIAL, CVM: 016306
# Processo: 613/770, Processando empresa: RUMO LOGÍSTICA OPERADORA MULTIMODAL S.A., CVM: 023450
# Processo: 614/770, Processando empresa: RUMO S.A., CVM: 017450
# Processo: 615/770, Processando empresa: SAINT-GOBAIN CANALIZAÇÃO S/A, CVM: 003689
# Processo: 616/770, Processando empresa: SAINT-GOBAIN VIDROS SA, CVM: 004189
# Processo: 617/770, Processando empresa: CIA SANEAMENTO BÁSICO ESTADO SÃO PAULO, CVM: 014443
# Processo: 618/770, Processando empresa: SADIA SA, CVM: 018848
# Processo: 619/770, Processando empresa: SAFIRA HOLDING S.A., CVM: 027138
# Processo: 620/770, Processando empresa: MASSA FALIDA DE SAM INDUSTRIAS SA, CVM: 012980
# Processo: 621/770, Processando empresa: SA MINERACAO DA TRINDADE, CVM: 010260
# Processo: 622/770, Processando empresa: CIA. DE SANEAMENTO DO PARANÁ - SANEPAR, CVM: 018627
# Processo: 623/770, Processando empresa: SANSUY SA INDÚSTRIA  DE PLASTICOS, CVM: 012696
# Processo: 624/770, Processando empresa: BANCO SANTANDER (BRASIL) S.A., CVM: 020532
# Processo: 625/770, Processando empresa: CIA TECIDOS SANTANENSE, CVM: 004081
# Processo: 626/770, Processando empresa: SANTISTA TEXTIL SA, CVM: 014516
# Processo: 627/770, Processando empresa: NUMERAL 80 PARTICIPAÇÕES S.A., CVM: 016446
# Processo: 628/770, Processando empresa: SANTOS BRASIL PARTICIPAÇÕES S.A., CVM: 017892
# Processo: 629/770, Processando empresa: SAO CARLOS EMPREEND E PARTICIPACOES S.A., CVM: 013781
# Processo: 630/770, Processando empresa: SÃO MARTINHO SA, CVM: 020516
# Processo: 631/770, Processando empresa: SARAIVA LIVREIROS S.A. - EM RECUPERAÇÃO JUDICIAL, CVM: 010472
# Processo: 632/770, Processando empresa: SAUIPE SA, CVM: 015261
# Processo: 633/770, Processando empresa: S.A. (VIAÇÃO AÉREA RIO-GRANDENSE) - FALIDA, CVM: 011681
# Processo: 634/770, Processando empresa: CIA INDUSTRIAL SCHLOSSER S.A., CVM: 003549
# Processo: 635/770, Processando empresa: SCHULZ SA, CVM: 014664
# Processo: 636/770, Processando empresa: SEARA ALIMENTOS SA, CVM: 018198
# Processo: 637/770, Processando empresa: PEARSON SISTEMAS DO BRASIL S.A., CVM: 017906
# Processo: 638/770, Processando empresa: CIA SEGUROS ALIANCA DA BAHIA, CVM: 003115
# Processo: 639/770, Processando empresa: CIA SEGUROS MINAS BRASIL, CVM: 003140
# Processo: 640/770, Processando empresa: INNCORP S.A., CVM: 017558
# Processo: 641/770, Processando empresa: SEMP TOSHIBA SA, CVM: 010588
# Processo: 642/770, Processando empresa: SEQUOIA LOGÍSTICA E TRANSPORTES S.A., CVM: 025160
# Processo: 643/770, Processando empresa: SER EDUCACIONAL S.A., CVM: 023221
# Processo: 644/770, Processando empresa: SERGEN SERVS GERAIS DE ENG SA, CVM: 010596
# Processo: 645/770, Processando empresa: MASSA FALIDA DA SHARP SA EQUIPS ELETRONICOS, CVM: 010642
# Processo: 646/770, Processando empresa: SHOPTIME SA, CVM: 015482
# Processo: 647/770, Processando empresa: SIBRA ELETROSIDERURGICA BRASILEIRA SA (atual Rio Doce Manganês S/A), CVM: 010669
# Processo: 648/770, Processando empresa: CIA SIDERURGICA NACIONAL, CVM: 004030
# Processo: 649/770, Processando empresa: COMPANHIA  SIDERÚRGICA  DE  TUBARÃO, CVM: 014117
# Processo: 650/770, Processando empresa: SIFCO SA, CVM: 010740
# Processo: 651/770, Processando empresa: SIMPAR S.A., CVM: 025003
# Processo: 652/770, Processando empresa: SINQIA S.A., CVM: 022799
# Processo: 653/770, Processando empresa: SLC AGRICOLA SA, CVM: 020745
# Processo: 654/770, Processando empresa: SMARTFIT ESCOLA DE GINÁSTICA E DANÇA S.A., CVM: 024260
# Processo: 655/770, Processando empresa: SMILES FIDELIDADE S.A., CVM: 024252
# Processo: 656/770, Processando empresa: BANCO SOFISA SA, CVM: 020680
# Processo: 657/770, Processando empresa: SOLA SA INDS ALIMENTICIAS, CVM: 014710
# Processo: 658/770, Processando empresa: SOMOS EDUCAÇÃO S.A., CVM: 022551
# Processo: 659/770, Processando empresa: SONDOTECNICA ENGENHARIA SOLOS S.A., CVM: 010880
# Processo: 660/770, Processando empresa: SOUTO VIDIGAL SA, CVM: 009547
# Processo: 661/770, Processando empresa: SOUZA CRUZ SA, CVM: 004057
# Processo: 662/770, Processando empresa: SPRINGER SA, CVM: 010960
# Processo: 663/770, Processando empresa: SPRINGS GLOBAL PARTICIPAÇÕES S/A, CVM: 020966
# Processo: 664/770, Processando empresa: SPSCS INDUSTRIAL SA, CVM: 001953
# Processo: 665/770, Processando empresa: SÃO PAULO TURISMO S.A., CVM: 009415
# Processo: 666/770, Processando empresa: STARA S.A. - INDÚSTRIA DE IMPLEMENTOS AGRÍCOLAS, CVM: 024201
# Processo: 667/770, Processando empresa: STATKRAFT ENERGIAS RENOVÁVEIS S.A., CVM: 022594
# Processo: 668/770, Processando empresa: BANCO SUDAMERIS BRASIL SA, CVM: 001422
# Processo: 669/770, Processando empresa: SUDESTE SA, CVM: 016586
# Processo: 670/770, Processando empresa: SUL 116 PARTICIPAÇÕES S.A., CVM: 016438
# Processo: 671/770, Processando empresa: SUL AMERICA CIA NACL SEGUROS, CVM: 011010
# Processo: 672/770, Processando empresa: SUL AMERICA S/A, CVM: 021121
# Processo: 673/770, Processando empresa: CONSTRUTORA SULTEPA S.A. - EM RECUPERAÇÃO JUDICIAL, CVM: 013030
# Processo: 674/770, Processando empresa: SUZANO HOLDING S.A., CVM: 009067
# Processo: 675/770, Processando empresa: SUZANO S.A., CVM: 013986
# Processo: 676/770, Processando empresa: SYN PROP & TECH S.A., CVM: 021040
# Processo: 677/770, Processando empresa: TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A., CVM: 020257
# Processo: 678/770, Processando empresa: TAM S.A., CVM: 016390
# Processo: 679/770, Processando empresa: TARPON INVESTIMENTOS S/A, CVM: 021717
# Processo: 680/770, Processando empresa: TAURUS ARMAS S.A., CVM: 006173
# Processo: 681/770, Processando empresa: TC S.A., CVM: 026077
# Processo: 682/770, Processando empresa: TECBLU - TECELAGEM BLUMENAU S/A., CVM: 011215
# Processo: 683/770, Processando empresa: FIACAO E TECELAGEM SAO JOSE S/A - EM RECUPERAÇÃO JUDICIAL, CVM: 005983
# Processo: 684/770, Processando empresa: TECHNOS SA, CVM: 022519
# Processo: 685/770, Processando empresa: TECHNOS RELOGIOS SA, CVM: 011169
# Processo: 686/770, Processando empresa: TECNISA S/A, CVM: 020435
# Processo: 687/770, Processando empresa: TECNOSOLO ENGENHARIA SA EMPRESA FALIDA, CVM: 011207
# Processo: 688/770, Processando empresa: TEC TOY S/A, CVM: 014133
# Processo: 689/770, Processando empresa: TEGMA GESTÃO LOGÍSTICA SA, CVM: 020800
# Processo: 690/770, Processando empresa: TEGRA INCORPORADORA S.A., CVM: 025844
# Processo: 691/770, Processando empresa: TEKA TECELAGEM KUEHNRICH SA - EM RECUPERAÇÃO JUDICIAL, CVM: 011223
# Processo: 692/770, Processando empresa: TEKNO S.A. INDÚSTRIA E COMÉRCIO, CVM: 011231
# Processo: 693/770, Processando empresa: TELE NORTE CELULAR PARTICIPAÇÕES SA, CVM: 017604
# Processo: 694/770, Processando empresa: TELEC. BRASILEIRAS S.A. - TELEBRÁS, CVM: 011258
# Processo: 695/770, Processando empresa: TELEFÔNICA BRASIL S.A., CVM: 017671
# Processo: 696/770, Processando empresa: TELE NORTE LESTE PARTICIPAÇÕES SA, CVM: 017655
# Processo: 697/770, Processando empresa: TELEMAR NORTE LESTE SA, CVM: 011320
# Processo: 698/770, Processando empresa: TELEMIG CELULAR SA, CVM: 017213
# Processo: 699/770, Processando empresa: TELEMIG CELULAR PARTICIPAÇÕES S.A., CVM: 017701
# Processo: 700/770, Processando empresa: TELINVEST SA, CVM: 017418
# Processo: 701/770, Processando empresa: TEMPO PARTICIPAÇOES S/A, CVM: 019917
# Processo: 702/770, Processando empresa: CONSTRUTORA TENDA S/A, CVM: 021148
# Processo: 703/770, Processando empresa: TEREOS INTERNACIONAL S/A, CVM: 022136
# Processo: 704/770, Processando empresa: TERRA SANTA PROPRIEDADES AGRÍCOLAS S.A., CVM: 026000
# Processo: 705/770, Processando empresa: TÊXTIL RENAUXVIEW S/A, CVM: 007544
# Processo: 706/770, Processando empresa: TIM S.A., CVM: 024929
# Processo: 707/770, Processando empresa: TIM NORDESTE TELECOMUNICAÇÕES S.A., CVM: 017078
# Processo: 708/770, Processando empresa: TIM SUL S.A., CVM: 017221
# Processo: 709/770, Processando empresa: T4F ENTRETENIMENTO SA, CVM: 022454
# Processo: 710/770, Processando empresa: TIVIT TERCEIRIZAÇÃO DE PROCESSOS, SERVIÇOS E TECNOLOGIA S/A, CVM: 021768
# Processo: 711/770, Processando empresa: TOTVS S.A, CVM: 019992
# Processo: 712/770, Processando empresa: TRACK & FIELD CO S.A, CVM: 025208
# Processo: 713/770, Processando empresa: TRAFO EQUIPAMENTOS ELETRICOS S.A., CVM: 011452
# Processo: 714/770, Processando empresa: CTEEP CIA TRANSM ENERGIA ELÉTR. PAULISTA, CVM: 018376
# Processo: 715/770, Processando empresa: TRANSBRASIL SA LINHAS AEREAS - FALIDA, CVM: 011479
# Processo: 716/770, Processando empresa: MASSA FALIDA DA TRANSPARANA SA, CVM: 011495
# Processo: 717/770, Processando empresa: TREVISA  INVESTIMENTOS SA, CVM: 008192
# Processo: 718/770, Processando empresa: TRISUL S/A, CVM: 021130
# Processo: 719/770, Processando empresa: TPI - TRIUNFO PARTICIPACOES E INVESTIMENTOS S.A., CVM: 019330
# Processo: 720/770, Processando empresa: TROMBINI SA ADM E PARTICIPACAO, CVM: 011517
# Processo: 721/770, Processando empresa: TRORION SA, CVM: 011525
# Processo: 722/770, Processando empresa: TUPY SA, CVM: 006343
# Processo: 723/770, Processando empresa: ULTRAPAR PARTICIPAÇÕES SA, CVM: 018465
# Processo: 724/770, Processando empresa: UNIBANCO UNIAO BANCOS BRAS SA, CVM: 011584
# Processo: 725/770, Processando empresa: UNIBANCO HOLDINGS S.A., CVM: 014753
# Processo: 726/770, Processando empresa: UNICASA INDÚSTRIA DE MÓVEIS S.A., CVM: 022780
# Processo: 727/770, Processando empresa: UNIFIQUE TELECOMUNICAÇÕES S.A., CVM: 026050
# Processo: 728/770, Processando empresa: UNIPAR CARBOCLORO S.A., CVM: 011592
# Processo: 729/770, Processando empresa: UNIVERSO ONLINE SA, CVM: 019887
# Processo: 730/770, Processando empresa: UPTICK PARTICIPACOES SA, CVM: 016624
# Processo: 731/770, Processando empresa: USINAS SID DE MINAS GERAIS S.A.-USIMINAS, CVM: 014320
# Processo: 732/770, Processando empresa: COSTA PINTO S.A., CVM: 012220
# Processo: 733/770, Processando empresa: VALE S.A., CVM: 004170
# Processo: 734/770, Processando empresa: VALE FERTILIZANTES S.A., CVM: 014028
# Processo: 735/770, Processando empresa: VALETRON SA, CVM: 016225
# Processo: 736/770, Processando empresa: VALID SOLUÇÕES S.A., CVM: 020028
# Processo: 737/770, Processando empresa: VAMOS LOCAÇÃO DE CAMINHÕES, MÁQUINAS E EQUIPAMENTOS S.A., CVM: 024716
# Processo: 738/770, Processando empresa: VARIG PARTIC. EM SERVIÇOS COMPLEMENTARES, CVM: 018694
# Processo: 739/770, Processando empresa: VARIG PARTICIPAÇÕES EM TRANSP AÉREOS S/A, CVM: 018686
# Processo: 740/770, Processando empresa: VIACAO AEREA S PAULO SA VASP, CVM: 011703
# Processo: 741/770, Processando empresa: VBC ENERGIA SA, CVM: 014540
# Processo: 742/770, Processando empresa: VESTE SA ESTILO, CVM: 021440
# Processo: 743/770, Processando empresa: VICUNHA TEXTIL SA, CVM: 005991
# Processo: 744/770, Processando empresa: SA FABRICA PRODS ALIMCS VIGOR, CVM: 010227
# Processo: 745/770, Processando empresa: VIGOR ALIMENTOS S.A., CVM: 022772
# Processo: 746/770, Processando empresa: VITTIA S.A., CVM: 025763
# Processo: 747/770, Processando empresa: VIVARA PARTICIPAÇÕES S.A., CVM: 024805
# Processo: 748/770, Processando empresa: VIVAX SA, CVM: 019950
# Processo: 749/770, Processando empresa: CM HOSPITALAR S.A, CVM: 025682
# Processo: 750/770, Processando empresa: VIVER INCORPORADORA E CONSTRUTORA S.A, CVM: 020702
# Processo: 751/770, Processando empresa: VIVO PARTICIPAÇÕES SA, CVM: 017710
# Processo: 752/770, Processando empresa: VOTEC TAXI AEREO SA, CVM: 011754
# Processo: 753/770, Processando empresa: VULCABRAS S.A., CVM: 011762
# Processo: 754/770, Processando empresa: LIVETECH DA BAHIA INDÚSTRIA E COMÉRCIO S.A., CVM: 025895
# Processo: 755/770, Processando empresa: WEG SA, CVM: 005410
# Processo: 756/770, Processando empresa: WEMBLEY SOCIEDADE ANÔNIMA, CVM: 011800
# Processo: 757/770, Processando empresa: WESTWING COMÉRCIO VAREJISTA S.A., CVM: 025518
# Processo: 758/770, Processando empresa: WETZEL S.A., CVM: 011991
# Processo: 759/770, Processando empresa: WHIRLPOOL S.A, CVM: 014346
# Processo: 760/770, Processando empresa: SA WHITE MARTINS, CVM: 010294
# Processo: 761/770, Processando empresa: WIEST SA, CVM: 014397
# Processo: 762/770, Processando empresa: WILSON SONS S.A., CVM: 026247
# Processo: 763/770, Processando empresa: WIZ CO PARTICIPAÇÕES E CORRETAGEM DE SEGUROS S.A., CVM: 023590
# Processo: 764/770, Processando empresa: WLM PART. E COMÉRCIO DE MÁQUINAS E VEÍCULOS S.A., CVM: 011070
# Processo: 765/770, Processando empresa: BS&C EMPREENDIMENTOS E PARTICIPAÇÕES S.A., CVM: 023779
# Processo: 766/770, Processando empresa: YARA BRASIL FERTILIZANTES, CVM: 000140
# Processo: 767/770, Processando empresa: YBYRA CAPITAL S.A, CVM: 016705
# Processo: 768/770, Processando empresa: YDUQS PARTICIPACOES S.A., CVM: 021016
# Processo: 769/770, Processando empresa: ZAIN PARTICIPAÇÕES S/A, CVM: 017361
# Processo: 770/770, Processando empresa: ZAMP S.A., CVM: 024317
