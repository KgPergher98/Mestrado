# %%
from brfinance import CVMAsyncBackend
import pandas
from datetime import datetime, date
import requests
from bs4 import BeautifulSoup
import re

# %%
class CVM():

    def __init__(self) -> None:

        self.cvm_http_client = CVMAsyncBackend()

    def get_cvm_categories(self):
        """ EXTRAI AS INFORMAÇÕES DE CATEGORIAS
            I.E. OS TIPOS DE DOCUMENTOS DISPONÍVEIS

            UTILIZA O BrFINANCE E DADOS DA CVM
        """
        categories = self.cvm_http_client.get_consulta_externa_cvm_categories()
        categories = pandas.DataFrame.from_dict(categories, orient = "index").reset_index()
        categories.columns = ["BrFin", "Description"]
        categories.to_csv("CategoriasDocsCVM.txt", index = False)

    def get_cvm_codes(self):
        """ EXTRAI OS CODIGOS CVM + STATUS CVM

            UTILIZA A BIBLIOTECA BrFINANCE E DADOS DA CVM
        """
        codes = self.cvm_http_client.get_cvm_codes()
        codes = pandas.DataFrame.from_dict(codes, orient = "index")
        pattern = r'\((.*?)\)'
        codes[1] = codes[0].str.extract(pattern).fillna("-")
        codes[0] = codes[0].str.replace(pattern, "", regex = True)
        codes = codes.reset_index()
        codes.columns = ["CVMCode", "FirmName", "CVMStatus"]
        codes.to_csv("CodigosDocsCVM.txt", index = False)

    def firms_informations(self, extract_data:bool = True, fetch_data:bool = True, fetch_br_fin:bool = False, record_file:str = "EmpresasBrasilCVM"):

        """ ADQUIRE INFORMAÇÕES DE COMPANHIAS ABERTAS BRASILEIRAS VIA CVM

            REFERENCIA DE SITE: https://cvmweb.cvm.gov.br/SWB/Sistemas/SCW/CPublica/CiaAb/FormBuscaCiaAbOrdAlf.aspx?LetraInicial=3

            EXTRACT_DATA [BOOL] > EXTRAI OS DADOS EM TABELAS, SEM CABEÇALHO E CRIA ARQUIVO DE REFERENCIA DE DADOS EM FORMATO .TXT
            FETCH_DATA   [BOOL] > AJUSTA DATAFRAME DE REFERÊNCIA CVM
            FETCH_BR_FIN [BOOL] > VERIFICA AS INFORMAÇÕES PRESENTES NA LIB BR_FINANCE
        """
        if extract_data:
            # INFORMAÇÕES SOBRE AS COMPANHIAS BRASILEIRAS
            infos = []

            # TODAS AS LETRAS MAIUSCULAS E NUMEROS
            # CONFORME MOSTRADO NO BUSCADOR DA CVM
            capital_letters_and_numbers = []

            # TODAS AS LETRAS MAIUSCULAS VIA ASCII
            for ascii_value in range(ord('A'), ord('Z') + 1):
                capital_letters_and_numbers.append(chr(ascii_value))

            # TODOS OS DIGITOS POSSIVEIS
            for digit in range(10):
                capital_letters_and_numbers.append(str(digit))

            # PARA CADA POSSIBILIDADE NAS LISTAS CRIADAS
            # TENTAMOS ACESSAR AS TABELAS DISPONIVEIS
            for focus in capital_letters_and_numbers:

                # USA O SITE BASE DA CVM E ALTERA A LETRA INICIAL PARA BUSCAR AS TABELAS
                url = f'https://cvmweb.cvm.gov.br//SWB//Sistemas//SCW//CPublica//CiaAb//FormBuscaCiaAbOrdAlf.aspx?LetraInicial={focus}'
                print(f"Researching firms: Start with {focus}")

                # USA O REQUEST PARA ACESSAR A URL
                response = requests.get(url)

                # SE O STATUS CODE = 200, ACESSO FOI UM SUCESSO
                if response.status_code == 200:

                    try:

                        # REALIZA O PARSING DO HTML VIA BEAUTIFULSOUP
                        html_content = response.text
                        soup = BeautifulSoup(html_content, 'html.parser')

                        # TODAS AS TABELAS NO HTML
                        tables = soup.find_all('table')

                        for table in tables:

                            # PROCESSAMOS OS ELEMENTOS 'TABELA'
                            rows = table.find_all('tr')

                            for row in rows:

                                # CÉLULAS DA TABELA
                                cells = row.find_all(['th', 'td'])
                                # TEXTO COMPLETO DE INFORMAÇÕES A SER EXTRAÍDO
                                full_txt = ""

                                for cell in cells:

                                    # ADQUIRE O TEXTO, SEM ESPAÇOS
                                    txt = cell.get_text(strip = True)

                                    if not txt.startswith(("CNPJ", "Selecione", " ")):

                                        # NÃO DESEJAMOS OS CABEÇALHOS PADRÃO
                                        full_txt += txt + ";"

                                    else: break

                                # CASO O TEXTO SEJA VALIDO, ACRESCENTA O ARQUIVO EMPRESAS BRASIL
                                if len(full_txt) > 0:

                                    infos.append(full_txt)                     

                    except Exception as exc:

                        # NOS AJUDA A COMPREENDER SE HOUVE UM ERRO E PORQUE
                        print(f"[ERROR] at {focus}: {exc}")

                else:

                    # NÃO FOI POSSIVEL REALIZAR O REQUEST
                    print(f"[WARNING] at {focus}: Response Status - {response.status_code}")

            # CRIA O ARQUIVO FINAL DE INFORMAÇÕES
            with open(record_file + ".txt", "w+") as record:
                for info in infos:
                    try:
                        record.write(info + "\n")
                    except Exception as exc:
                        print(info, exc)

        if fetch_data:

            # MESMA REFERÊNCIA DE FORMATO UTILIZADA PELO BrFINANCE
            def format_number(number):
                return f'{number:06d}'

            # EXTRAI O DATAFRAME DE INFORMAÇÕES DA CVM
            df = pandas.read_csv(
                record_file + ".txt", sep = ";", encoding = "latin1", header = None
            ).dropna(axis = 1)
            # NOME PADRÃO DAS COLUNAS
            df.columns = ["CNPJ", "FIRM_NAME", "CVM_FIRM_TYPE", "CVM_CODE", "CVM_STATUS"]
            # CORRIGE OS CÓDIGOS
            df["CVM_CODE"] = df["CVM_CODE"].apply(format_number)
            # SOBSCREVE AS INFORMAÇÕES
            df.to_csv(record_file + ".txt", index = False)

        if fetch_br_fin:

            cvm_codes = self.cvm_http_client.get_cvm_codes()
            df = pandas.read_csv(record_file + ".txt")
            print(cvm_codes)
            print(df)

    def get_selected_firms(self):

        df = pandas.read_csv("feeder_db//Brazil.txt")
        df = df[(df.CNPJ != "-") & (df.CVM_CODE != "-")]
        self.firms = df.copy()
        display(df)
    
    def documents_cvm(self, start_date = date(1995,12,31)):

        CVM.get_selected_firms(self)

        categories = pandas.read_csv("feeder_db//CategoriasDocsCVM.txt")["BrFin"].tolist()

        for cvm_code in self.firms["CVM_CODE"].unique():

            got = False
            retries = 0

            while not got:

                try:

                    if retries < 3:

                        search_result = self.cvm_http_client.get_consulta_externa_cvm_results(
                            start_date = start_date,
                            end_date = date.today(),
                            cod_cvm = [cvm_code],
                            participant_type = [1],
                            category = categories,
                            last_ref_date = False
                        )

                        search_result.to_csv(f"cvm//Docs_CVM_{cvm_code}.txt")
                        print(f"Dados armazenados com sucesso - CVM {cvm_code}")

                    got = True

                except Exception as exc:

                    retries += 1
                    print(f"ERROR - Aquisicao de dados CVM - Code: {cvm_code} - Retry: {retries}")

# %%
cvm = CVM()
#cvm.get_cvm_categories()
#cvm.get_cvm_codes()
#cvm.firms_informations(extract_data = False, fetch_data = False, fetch_br_fin = True)
cvm.documents_cvm()
# Out:
#                   NAME         CLASS                CODE                CNPJ  \
# 0         3R PETROLEUM            ON               RRRP3  12.091.809/0001-55
# 1              3TENTOS            ON               TTEN3  94.813.102/0001-70
# 2         521 PARTICIP            ON              QVUM3B  01.547.749/0001-16
# 3         524 PARTICIP            ON               QVQP3  01.851.771/0001-55
# 4    A P PARTICIPACOES         ON;PN         APPA3;APPA4  02.288.752/0001-25
# ..                 ...           ...                 ...                 ...
# 897        YARA BRASIL         ON;PN         ILMD3;ILMD4  92.660.604/0001-82
# 898          YBYRA S/A            ON               YBRA3  02.217.319/0001-07
# 899         YDUQS PART  ON;PN;UNT N2  YDUQ3;ESTC4;ESTC11  08.807.432/0001-10
# 900          ZAIN PART            ON              OPZI3B  02.363.918/0001-20
# 901          ZAMP S.A.            ON               ZAMP3  13.574.594/0001-96
#
#     STOCK_TYPE                       ISIN                  SETOR(BOVESPA)  \
# 0         AÇÃO               BRRRRPACNOR5  PETRÓLEO GÁS E BIOCOMBUSTÍVEIS
# 1         AÇÃO               BRTTENACNOR0             CONSUMO NÃO CÍCLICO
# 2         AÇÃO                          -                               -
# 3         AÇÃO               BRQVQPACNOR1                          OUTROS
# 4         AÇÃO                          -                               -
# ..         ...                        ...                             ...
# 897       AÇÃO  BRILMDACNOR4;BRILMDACNPR1                               -
# 898       AÇÃO               BRYBRAACNOR7                          OUTROS
# 899       AÇÃO             BRYDUQACNOR3;-                 CONSUMO CÍCLICO
# 900       AÇÃO               BROPZIACNOR4                      FINANCEIRO
# 901       AÇÃO               BRZAMPACNOR5                 CONSUMO CÍCLICO
#
#                   SUBSETOR(BOVESPA)                 SEGMENTO(BOVESPA)  \
# 0    PETRÓLEO GÁS E BIOCOMBUSTÍVEIS  EXPLORAÇÃO REFINO E DISTRIBUIÇÃO
# 1                      AGROPECUÁRIA                       AGRICULTURA
# 2                                 -                                 -
# 3                            OUTROS                            OUTROS
# 4                                 -                                 -
# ..                              ...                               ...
# 897                               -                                 -
# 898                          OUTROS                            OUTROS
# 899                        DIVERSOS             SERVIÇOS EDUCACIONAIS
# 900                          OUTROS                            OUTROS
# 901           HOTÉIS E RESTAURANTES           RESTAURANTE E SIMILARES
#
#     CVM_CODE               CVM_STATUS CVM_FIRM_TYPE  \
# 0     025291  Concedido em 09/11/2020  CIAS ABERTAS
# 1     025950  Concedido em 21/06/2021  CIAS ABERTAS
# 2     016330  Concedido em 11/07/1997  CIAS ABERTAS
# 3     016284  Concedido em 30/05/1997  CIAS ABERTAS
# 4     016802  Cancelado em 23/12/2004  CIAS ABERTAS
# ..       ...                      ...           ...
# 897   000140  Cancelado em 18/11/2011  CIAS ABERTAS
# 898   016705  Concedido em 08/12/1997  CIAS ABERTAS
# 899   021016  Concedido em 26/07/2007  CIAS ABERTAS
# 900   017361  Cancelado em 14/08/2020  CIAS ABERTAS
# 901   024317  Concedido em 14/12/2017  CIAS ABERTAS
#
#                                              FIRM_NAME  SOURCE_ECONOMATICA  \
# 0                         3R PETROLEUM OLÉO E GÁS S.A.                True
# 1                      TRÊS TENTOS AGROINDUSTRIAL S.A.                True
# 2    521 PARTICIPAÇOES S.A. - EM LIQUIDAÇÃO EXTRAJU...                True
# 3                                 524 PARTICIPAÇOES SA                True
# 4                                A.P. PARTICIPAÇOES SA                True
# ..                                                 ...                 ...
# 897                          YARA BRASIL FERTILIZANTES                True
# 898                                  YBYRA CAPITAL S.A                True
# 899                           YDUQS PARTICIPACOES S.A.                True
# 900                             ZAIN PARTICIPAÇÕES S/A                True
# 901                                          ZAMP S.A.                True
#
#      SOURCE_CVM  SOURCE_BRFIN
# 0          True         False
# 1          True         False
# 2          True         False
# 3          True         False
# 4          True         False
# ..          ...           ...
# 897        True         False
# 898        True         False
# 899        True         False
# 900        True         False
# 901        True         False
#
# [770 rows x 16 columns]
# Dados armazenados com sucesso - CVM 025291
# Dados armazenados com sucesso - CVM 025950
# Dados armazenados com sucesso - CVM 016330
# Dados armazenados com sucesso - CVM 016284
# Dados armazenados com sucesso - CVM 016802
# Dados armazenados com sucesso - CVM 020958
# ERROR - Aquisicao de dados CVM - Code: 020206 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020206 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020206 - Retry: 3
# Dados armazenados com sucesso - CVM 005380
# Dados armazenados com sucesso - CVM 000108
# Dados armazenados com sucesso - CVM 021725
# Dados armazenados com sucesso - CVM 025283
# Dados armazenados com sucesso - CVM 025640
# Dados armazenados com sucesso - CVM 019313
# Dados armazenados com sucesso - CVM 016527
# Dados armazenados com sucesso - CVM 018350
# Dados armazenados com sucesso - CVM 026174
# Dados armazenados com sucesso - CVM 018104
# Dados armazenados com sucesso - CVM 020150
# Dados armazenados com sucesso - CVM 022179
# Dados armazenados com sucesso - CVM 019437
# Dados armazenados com sucesso - CVM 012343
# Dados armazenados com sucesso - CVM 019062
# ERROR - Aquisicao de dados CVM - Code: 020664 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020664 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020664 - Retry: 3
# Dados armazenados com sucesso - CVM 000183
# Dados armazenados com sucesso - CVM 021911
# Dados armazenados com sucesso - CVM 025933
# Dados armazenados com sucesso - CVM 010570
# Dados armazenados com sucesso - CVM 025658
# Dados armazenados com sucesso - CVM 000248
# Dados armazenados com sucesso - CVM 004707
# Dados armazenados com sucesso - CVM 003891
# Dados armazenados com sucesso - CVM 009954
# Dados armazenados com sucesso - CVM 001384
# Dados armazenados com sucesso - CVM 021300
# Dados armazenados com sucesso - CVM 022357
# Dados armazenados com sucesso - CVM 012823
# Dados armazenados com sucesso - CVM 015300
# ERROR - Aquisicao de dados CVM - Code: 024058 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 024058 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 024058 - Retry: 3
# Dados armazenados com sucesso - CVM 025330
# Dados armazenados com sucesso - CVM 020850
# Dados armazenados com sucesso - CVM 010456
# Dados armazenados com sucesso - CVM 022217
# Dados armazenados com sucesso - CVM 025275
# Dados armazenados com sucesso - CVM 018066
# Dados armazenados com sucesso - CVM 023183
# Dados armazenados com sucesso - CVM 021490
# Dados armazenados com sucesso - CVM 002658
# Dados armazenados com sucesso - CVM 000361
# Dados armazenados com sucesso - CVM 000922
# Dados armazenados com sucesso - CVM 017280
# Dados armazenados com sucesso - CVM 023264
# Dados armazenados com sucesso - CVM 024961
# Dados armazenados com sucesso - CVM 012750
# Dados armazenados com sucesso - CVM 000787
# Dados armazenados com sucesso - CVM 020990
# Dados armazenados com sucesso - CVM 021172
# Dados armazenados com sucesso - CVM 003050
# Dados armazenados com sucesso - CVM 020214
# Dados armazenados com sucesso - CVM 021458
# Dados armazenados com sucesso - CVM 018961
# Dados armazenados com sucesso - CVM 023248
# Dados armazenados com sucesso - CVM 003581
# Dados armazenados com sucesso - CVM 002755
# Dados armazenados com sucesso - CVM 013188
# Dados armazenados com sucesso - CVM 006998
# ERROR - Aquisicao de dados CVM - Code: 000434 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 000434 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 000434 - Retry: 3
# Dados armazenados com sucesso - CVM 018651
# Dados armazenados com sucesso - CVM 003964
# Dados armazenados com sucesso - CVM 022349
# Dados armazenados com sucesso - CVM 026069
# Dados armazenados com sucesso - CVM 000523
# ERROR - Aquisicao de dados CVM - Code: 015881 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 015881 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 015881 - Retry: 3
# Dados armazenados com sucesso - CVM 019771
# ERROR - Aquisicao de dados CVM - Code: 000574 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 000574 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 000574 - Retry: 3
# Dados armazenados com sucesso - CVM 025372
# Dados armazenados com sucesso - CVM 019100
# Dados armazenados com sucesso - CVM 015423
# Dados armazenados com sucesso - CVM 026620
# Dados armazenados com sucesso - CVM 022381
# Dados armazenados com sucesso - CVM 011975
# Dados armazenados com sucesso - CVM 024112
# Dados armazenados com sucesso - CVM 012319
# Dados armazenados com sucesso - CVM 021610
# Dados armazenados com sucesso - CVM 000701
# Dados armazenados com sucesso - CVM 018155
# Dados armazenados com sucesso - CVM 002810
# Dados armazenados com sucesso - CVM 001147
# Dados armazenados com sucesso - CVM 024600
# Dados armazenados com sucesso - CVM 024406
# Dados armazenados com sucesso - CVM 021199
# Dados armazenados com sucesso - CVM 016985
# Dados armazenados com sucesso - CVM 000841
# Dados armazenados com sucesso - CVM 001120
# Dados armazenados com sucesso - CVM 001112
# Dados armazenados com sucesso - CVM 001180
# Dados armazenados com sucesso - CVM 001155
# Dados armazenados com sucesso - CVM 008176
# Dados armazenados com sucesso - CVM 001171
# Dados armazenados com sucesso - CVM 001210
# Dados armazenados com sucesso - CVM 001520
# Dados armazenados com sucesso - CVM 001562
# Dados armazenados com sucesso - CVM 024660
# Dados armazenados com sucesso - CVM 023159
# Dados armazenados com sucesso - CVM 000957
# Dados armazenados com sucesso - CVM 016233
# Dados armazenados com sucesso - CVM 020656
# Dados armazenados com sucesso - CVM 025500
# Dados armazenados com sucesso - CVM 001651
# Dados armazenados com sucesso - CVM 001660
# Dados armazenados com sucesso - CVM 017884
# Dados armazenados com sucesso - CVM 020907
# Dados armazenados com sucesso - CVM 001694
# Dados armazenados com sucesso - CVM 021113
# Dados armazenados com sucesso - CVM 001708
# Dados armazenados com sucesso - CVM 019305
# Dados armazenados com sucesso - CVM 022845
# Dados armazenados com sucesso - CVM 024627
# Dados armazenados com sucesso - CVM 017760
# Dados armazenados com sucesso - CVM 025704
# Dados armazenados com sucesso - CVM 025135
# Dados armazenados com sucesso - CVM 012190
# Dados armazenados com sucesso - CVM 015202
# Dados armazenados com sucesso - CVM 014435
# Dados armazenados com sucesso - CVM 016560
# ERROR - Aquisicao de dados CVM - Code: 010987 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 010987 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 010987 - Retry: 3
# Dados armazenados com sucesso - CVM 017353
# Dados armazenados com sucesso - CVM 023710
# Dados armazenados com sucesso - CVM 019909
# Dados armazenados com sucesso - CVM 025860
# Dados armazenados com sucesso - CVM 022500
# Dados armazenados com sucesso - CVM 019925
# Dados armazenados com sucesso - CVM 000906
# Dados armazenados com sucesso - CVM 018724
# Dados armazenados com sucesso - CVM 007714
# Dados armazenados com sucesso - CVM 001023
# Dados armazenados com sucesso - CVM 020036
# Dados armazenados com sucesso - CVM 001910
# Dados armazenados com sucesso - CVM 004820
# Dados armazenados com sucesso - CVM 001970
# Dados armazenados com sucesso - CVM 003506
# Dados armazenados com sucesso - CVM 017922
# Dados armazenados com sucesso - CVM 014206
# Dados armazenados com sucesso - CVM 016292
# Dados armazenados com sucesso - CVM 026085
# Dados armazenados com sucesso - CVM 020265
# Dados armazenados com sucesso - CVM 023817
# Dados armazenados com sucesso - CVM 012971
# Dados armazenados com sucesso - CVM 022616
# Dados armazenados com sucesso - CVM 002038
# Dados armazenados com sucesso - CVM 002593
# Dados armazenados com sucesso - CVM 010278
# Dados armazenados com sucesso - CVM 008370
# Dados armazenados com sucesso - CVM 019119
# Dados armazenados com sucesso - CVM 016322
# Dados armazenados com sucesso - CVM 002909
# Dados armazenados com sucesso - CVM 019135
# Dados armazenados com sucesso - CVM 013552
# Dados armazenados com sucesso - CVM 002062
# Dados armazenados com sucesso - CVM 019097
# Dados armazenados com sucesso - CVM 023795
# Dados armazenados com sucesso - CVM 002100
# Dados armazenados com sucesso - CVM 024228
# Dados armazenados com sucesso - CVM 017493
# Dados armazenados com sucesso - CVM 010863
# Dados armazenados com sucesso - CVM 024171
# Dados armazenados com sucesso - CVM 002178
# Dados armazenados com sucesso - CVM 016861
# Dados armazenados com sucesso - CVM 006505
# Dados armazenados com sucesso - CVM 025984
# Dados armazenados com sucesso - CVM 013315
# Dados armazenados com sucesso - CVM 017728
# Dados armazenados com sucesso - CVM 020486
# Dados armazenados com sucesso - CVM 018821
# Dados armazenados com sucesso - CVM 020184
# Dados armazenados com sucesso - CVM 024848
# Dados armazenados com sucesso - CVM 014451
# Dados armazenados com sucesso - CVM 003077
# Dados armazenados com sucesso - CVM 020648
# Dados armazenados com sucesso - CVM 027154
# Dados armazenados com sucesso - CVM 003204
# ERROR - Aquisicao de dados CVM - Code: 016616 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 016616 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 016616 - Retry: 3
# Dados armazenados com sucesso - CVM 002461
# Dados armazenados com sucesso - CVM 025577
# Dados armazenados com sucesso - CVM 021393
# ERROR - Aquisicao de dados CVM - Code: 002402 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 002402 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 002402 - Retry: 3
# Dados armazenados com sucesso - CVM 014362
# Dados armazenados com sucesso - CVM 013854
# Dados armazenados com sucesso - CVM 002453
# Dados armazenados com sucesso - CVM 021245
# Dados armazenados com sucesso - CVM 020176
# Dados armazenados com sucesso - CVM 002577
# Dados armazenados com sucesso - CVM 015288
# Dados armazenados com sucesso - CVM 021792
# Dados armazenados com sucesso - CVM 010243
# Dados armazenados com sucesso - CVM 002488
# Dados armazenados com sucesso - CVM 014761
# Dados armazenados com sucesso - CVM 021733
# Dados armazenados com sucesso - CVM 002933
# Dados armazenados com sucesso - CVM 003468
# ERROR - Aquisicao de dados CVM - Code: 006513 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 006513 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 006513 - Retry: 3
# Dados armazenados com sucesso - CVM 014818
# Dados armazenados com sucesso - CVM 023965
# Dados armazenados com sucesso - CVM 513806
# Dados armazenados com sucesso - CVM 026093
# Dados armazenados com sucesso - CVM 013323
# Dados armazenados com sucesso - CVM 019089
# Dados armazenados com sucesso - CVM 004448
# Dados armazenados com sucesso - CVM 014524
# Dados armazenados com sucesso - CVM 014869
# Dados armazenados com sucesso - CVM 004480
# Dados armazenados com sucesso - CVM 017973
# Dados armazenados com sucesso - CVM 007552
# Dados armazenados com sucesso - CVM 012459
# Dados armazenados com sucesso - CVM 026280
# Dados armazenados com sucesso - CVM 015636
# Dados armazenados com sucesso - CVM 019046
# Dados armazenados com sucesso - CVM 025127
# Dados armazenados com sucesso - CVM 019208
# Dados armazenados com sucesso - CVM 004650
# Dados armazenados com sucesso - CVM 004723
# Dados armazenados com sucesso - CVM 004758
# Dados armazenados com sucesso - CVM 006327
# Dados armazenados com sucesso - CVM 003816
# Dados armazenados com sucesso - CVM 019445
# Dados armazenados com sucesso - CVM 014311
# Dados armazenados com sucesso - CVM 014044
# Dados armazenados com sucesso - CVM 004863
# Dados armazenados com sucesso - CVM 004839
# Dados armazenados com sucesso - CVM 019836
# Dados armazenados com sucesso - CVM 023485
# Dados armazenados com sucesso - CVM 018139
# Dados armazenados com sucesso - CVM 018317
# Dados armazenados com sucesso - CVM 003158
# Dados armazenados com sucesso - CVM 018660
# Dados armazenados com sucesso - CVM 018953
# Dados armazenados com sucesso - CVM 019275
# Dados armazenados com sucesso - CVM 020540
# Dados armazenados com sucesso - CVM 020141
# Dados armazenados com sucesso - CVM 011398
# Dados armazenados com sucesso - CVM 003913
# Dados armazenados com sucesso - CVM 025526
# Dados armazenados com sucesso - CVM 020753
# Dados armazenados com sucesso - CVM 025585
# Dados armazenados com sucesso - CVM 020044
# ERROR - Aquisicao de dados CVM - Code: 023981 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 023981 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 023981 - Retry: 3
# Dados armazenados com sucesso - CVM 025100
# Dados armazenados com sucesso - CVM 023310
# Dados armazenados com sucesso - CVM 014460
# Dados armazenados com sucesso - CVM 012742
# Dados armazenados com sucesso - CVM 005029
# Dados armazenados com sucesso - CVM 025046
# Dados armazenados com sucesso - CVM 016950
# Dados armazenados com sucesso - CVM 019623
# ERROR - Aquisicao de dados CVM - Code: 020095 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020095 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020095 - Retry: 3
# Dados armazenados com sucesso - CVM 020796
# Dados armazenados com sucesso - CVM 026026
# Dados armazenados com sucesso - CVM 021091
# Dados armazenados com sucesso - CVM 016632
# Dados armazenados com sucesso - CVM 005150
# ERROR - Aquisicao de dados CVM - Code: 013838 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 013838 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 013838 - Retry: 3
# Dados armazenados com sucesso - CVM 009342
# Dados armazenados com sucesso - CVM 020052
# Dados armazenados com sucesso - CVM 021350
# Dados armazenados com sucesso - CVM 014931
# Dados armazenados com sucesso - CVM 006076
# Dados armazenados com sucesso - CVM 003174
# Dados armazenados com sucesso - CVM 003182
# Dados armazenados com sucesso - CVM 005207
# Dados armazenados com sucesso - CVM 023493
# Dados armazenados com sucesso - CVM 019070
# Dados armazenados com sucesso - CVM 022284
# Dados armazenados com sucesso - CVM 025836
# Dados armazenados com sucesso - CVM 011363
# Dados armazenados com sucesso - CVM 018597
# Dados armazenados com sucesso - CVM 005339
# Dados armazenados com sucesso - CVM 001244
# Dados armazenados com sucesso - CVM 019453
# Dados armazenados com sucesso - CVM 005363
# Dados armazenados com sucesso - CVM 002763
# Dados armazenados com sucesso - CVM 010006
# Dados armazenados com sucesso - CVM 004359
# Dados armazenados com sucesso - CVM 017485
# Dados armazenados com sucesso - CVM 002437
# Dados armazenados com sucesso - CVM 025569
# Dados armazenados com sucesso - CVM 016209
# Dados armazenados com sucesso - CVM 015784
# Dados armazenados com sucesso - CVM 014176
# Dados armazenados com sucesso - CVM 012238
# Dados armazenados com sucesso - CVM 015598
# Dados armazenados com sucesso - CVM 016993
# Dados armazenados com sucesso - CVM 015458
# ERROR - Aquisicao de dados CVM - Code: 020087 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020087 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020087 - Retry: 3
# Dados armazenados com sucesso - CVM 017647
# ERROR - Aquisicao de dados CVM - Code: 022365 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 022365 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 022365 - Retry: 3
# Dados armazenados com sucesso - CVM 016497
# Dados armazenados com sucesso - CVM 019763
# ERROR - Aquisicao de dados CVM - Code: 015253 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 015253 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 015253 - Retry: 3
# Dados armazenados com sucesso - CVM 014605
# Dados armazenados com sucesso - CVM 005576
# Dados armazenados com sucesso - CVM 021237
# Dados armazenados com sucesso - CVM 017329
# Dados armazenados com sucesso - CVM 025259
# Dados armazenados com sucesso - CVM 012211
# Dados armazenados com sucesso - CVM 016608
# Dados armazenados com sucesso - CVM 018309
# ERROR - Aquisicao de dados CVM - Code: 020010 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020010 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020010 - Retry: 3
# Dados armazenados com sucesso - CVM 005690
# Dados armazenados com sucesso - CVM 015342
# Dados armazenados com sucesso - CVM 025445
# Dados armazenados com sucesso - CVM 024953
# Dados armazenados com sucesso - CVM 008427
# Dados armazenados com sucesso - CVM 005762
# Dados armazenados com sucesso - CVM 005770
# Dados armazenados com sucesso - CVM 026700
# Dados armazenados com sucesso - CVM 020524
# Dados armazenados com sucesso - CVM 001570
# Dados armazenados com sucesso - CVM 020770
# Dados armazenados com sucesso - CVM 003271
# Dados armazenados com sucesso - CVM 004138
# Dados armazenados com sucesso - CVM 005827
# Dados armazenados com sucesso - CVM 005924
# Dados armazenados com sucesso - CVM 020621
# Dados armazenados com sucesso - CVM 003069
# Dados armazenados com sucesso - CVM 003808
# Dados armazenados com sucesso - CVM 005940
# Dados armazenados com sucesso - CVM 006017
# Dados armazenados com sucesso - CVM 012793
# Dados armazenados com sucesso - CVM 020630
# Dados armazenados com sucesso - CVM 021881
# Dados armazenados com sucesso - CVM 024350
# Dados armazenados com sucesso - CVM 003263
# Dados armazenados com sucesso - CVM 025488
# Dados armazenados com sucesso - CVM 023736
# Dados armazenados com sucesso - CVM 011967
# Dados armazenados com sucesso - CVM 006211
# Dados armazenados com sucesso - CVM 017388
# ERROR - Aquisicao de dados CVM - Code: 016101 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 016101 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 016101 - Retry: 3
# Dados armazenados com sucesso - CVM 017965
# Dados armazenados com sucesso - CVM 006378
# Dados armazenados com sucesso - CVM 021008
# Dados armazenados com sucesso - CVM 018031
# Dados armazenados com sucesso - CVM 018368
# Dados armazenados com sucesso - CVM 005630
# Dados armazenados com sucesso - CVM 003980
# Dados armazenados com sucesso - CVM 008656
# Dados armazenados com sucesso - CVM 026140
# Dados armazenados com sucesso - CVM 025887
# Dados armazenados com sucesso - CVM 006483
# Dados armazenados com sucesso - CVM 019569
# Dados armazenados com sucesso - CVM 025712
# Dados armazenados com sucesso - CVM 006572
# Dados armazenados com sucesso - CVM 004537
# Dados armazenados com sucesso - CVM 019615
# Dados armazenados com sucesso - CVM 015695
# Dados armazenados com sucesso - CVM 025186
# Dados armazenados com sucesso - CVM 024783
# Dados armazenados com sucesso - CVM 024694
# Dados armazenados com sucesso - CVM 025011
# Dados armazenados com sucesso - CVM 014915
# ERROR - Aquisicao de dados CVM - Code: 020940 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020940 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020940 - Retry: 3
# Dados armazenados com sucesso - CVM 004669
# ERROR - Aquisicao de dados CVM - Code: 020117 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020117 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020117 - Retry: 3
# Dados armazenados com sucesso - CVM 003298
# Dados armazenados com sucesso - CVM 013366
# Dados armazenados com sucesso - CVM 024392
# Dados armazenados com sucesso - CVM 022578
# Dados armazenados com sucesso - CVM 025402
# Dados armazenados com sucesso - CVM 020877
# Dados armazenados com sucesso - CVM 006629
# Dados armazenados com sucesso - CVM 022675
# Dados armazenados com sucesso - CVM 025674
# Dados armazenados com sucesso - CVM 006700
# Dados armazenados com sucesso - CVM 000728
# Dados armazenados com sucesso - CVM 021431
# Dados armazenados com sucesso - CVM 016730
# Dados armazenados com sucesso - CVM 006815
# Dados armazenados com sucesso - CVM 023175
# Dados armazenados com sucesso - CVM 003336
# Dados armazenados com sucesso - CVM 020494
# Dados armazenados com sucesso - CVM 008672
# Dados armazenados com sucesso - CVM 024090
# Dados armazenados com sucesso - CVM 022438
# Dados armazenados com sucesso - CVM 023574
# Dados armazenados com sucesso - CVM 014567
# Dados armazenados com sucesso - CVM 006874
# Dados armazenados com sucesso - CVM 003395
# Dados armazenados com sucesso - CVM 020885
# Dados armazenados com sucesso - CVM 007595
# Dados armazenados com sucesso - CVM 025747
# Dados armazenados com sucesso - CVM 025453
# Dados armazenados com sucesso - CVM 024279
# Dados armazenados com sucesso - CVM 024384
# Dados armazenados com sucesso - CVM 018775
# Dados armazenados com sucesso - CVM 006041
# Dados armazenados com sucesso - CVM 011932
# Dados armazenados com sucesso - CVM 005193
# Dados armazenados com sucesso - CVM 002860
# Dados armazenados com sucesso - CVM 009997
# Dados armazenados com sucesso - CVM 002429
# Dados armazenados com sucesso - CVM 024180
# Dados armazenados com sucesso - CVM 015865
# Dados armazenados com sucesso - CVM 007617
# Dados armazenados com sucesso - CVM 012530
# Dados armazenados com sucesso - CVM 019348
# Dados armazenados com sucesso - CVM 012866
# Dados armazenados com sucesso - CVM 025496
# Dados armazenados com sucesso - CVM 007781
# Dados armazenados com sucesso - CVM 020575
# Dados armazenados com sucesso - CVM 020605
# Dados armazenados com sucesso - CVM 007811
# Dados armazenados com sucesso - CVM 013285
# Dados armazenados com sucesso - CVM 022020
# Dados armazenados com sucesso - CVM 025798
# Dados armazenados com sucesso - CVM 004146
# Dados armazenados com sucesso - CVM 007870
# Dados armazenados com sucesso - CVM 012653
# Dados armazenados com sucesso - CVM 020249
# Dados armazenados com sucesso - CVM 025879
# Dados armazenados com sucesso - CVM 000566
# Dados armazenados com sucesso - CVM 012262
# Dados armazenados com sucesso - CVM 007978
# Dados armazenados com sucesso - CVM 025062
# Dados armazenados com sucesso - CVM 025542
# Dados armazenados com sucesso - CVM 003603
# Dados armazenados com sucesso - CVM 017442
# Dados armazenados com sucesso - CVM 023299
# Dados armazenados com sucesso - CVM 008028
# Dados armazenados com sucesso - CVM 024872
# Dados armazenados com sucesso - CVM 019879
# Dados armazenados com sucesso - CVM 007056
# Dados armazenados com sucesso - CVM 023035
# Dados armazenados com sucesso - CVM 015091
# Dados armazenados com sucesso - CVM 024759
# ERROR - Aquisicao de dados CVM - Code: 008060 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 008060 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 008060 - Retry: 3
# Dados armazenados com sucesso - CVM 004774
# Dados armazenados com sucesso - CVM 019739
# Dados armazenados com sucesso - CVM 022691
# Dados armazenados com sucesso - CVM 024910
# Dados armazenados com sucesso - CVM 023272
# Dados armazenados com sucesso - CVM 020710
# Dados armazenados com sucesso - CVM 008087
# Dados armazenados com sucesso - CVM 015083
# Dados armazenados com sucesso - CVM 008117
# Dados armazenados com sucesso - CVM 022055
# Dados armazenados com sucesso - CVM 008133
# Dados armazenados com sucesso - CVM 017434
# Dados armazenados com sucesso - CVM 020370
# Dados armazenados com sucesso - CVM 003611
# Dados armazenados com sucesso - CVM 020060
# Dados armazenados com sucesso - CVM 505820
# Dados armazenados com sucesso - CVM 020338
# Dados armazenados com sucesso - CVM 007439
# Dados armazenados com sucesso - CVM 023612
# Dados armazenados com sucesso - CVM 022470
# Dados armazenados com sucesso - CVM 020842
# Dados armazenados com sucesso - CVM 018520
# Dados armazenados com sucesso - CVM 005088
# Dados armazenados com sucesso - CVM 014834
# Dados armazenados com sucesso - CVM 008389
# Dados armazenados com sucesso - CVM 008397
# Dados armazenados com sucesso - CVM 008400
# Dados armazenados com sucesso - CVM 017779
# Dados armazenados com sucesso - CVM 012181
# Dados armazenados com sucesso - CVM 008451
# Dados armazenados com sucesso - CVM 020788
# Dados armazenados com sucesso - CVM 008486
# Dados armazenados com sucesso - CVM 025690
# Dados armazenados com sucesso - CVM 015504
# Dados armazenados com sucesso - CVM 020273
# Dados armazenados com sucesso - CVM 003654
# Dados armazenados com sucesso - CVM 025232
# Dados armazenados com sucesso - CVM 025119
# ERROR - Aquisicao de dados CVM - Code: 014532 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 014532 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 014532 - Retry: 3
# Dados armazenados com sucesso - CVM 004782
# Dados armazenados com sucesso - CVM 018538
# Dados armazenados com sucesso - CVM 008540
# Dados armazenados com sucesso - CVM 001309
# Dados armazenados com sucesso - CVM 001317
# Dados armazenados com sucesso - CVM 001325
# Dados armazenados com sucesso - CVM 008559
# Dados armazenados com sucesso - CVM 008648
# Dados armazenados com sucesso - CVM 008605
# Dados armazenados com sucesso - CVM 008575
# Dados armazenados com sucesso - CVM 020613
# Dados armazenados com sucesso - CVM 008753
# Dados armazenados com sucesso - CVM 017876
# Dados armazenados com sucesso - CVM 007447
# Dados armazenados com sucesso - CVM 022012
# Dados armazenados com sucesso - CVM 008818
# ERROR - Aquisicao de dados CVM - Code: 020931 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020931 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020931 - Retry: 3
# Dados armazenados com sucesso - CVM 013765
# Dados armazenados com sucesso - CVM 024902
# Dados armazenados com sucesso - CVM 017914
# Dados armazenados com sucesso - CVM 025461
# Dados armazenados com sucesso - CVM 025755
# Dados armazenados com sucesso - CVM 008893
# Dados armazenados com sucesso - CVM 008907
# Dados armazenados com sucesso - CVM 025470
# Dados armazenados com sucesso - CVM 021067
# Dados armazenados com sucesso - CVM 023825
# Dados armazenados com sucesso - CVM 017949
# Dados armazenados com sucesso - CVM 020915
# Dados armazenados com sucesso - CVM 008982
# ERROR - Aquisicao de dados CVM - Code: 026034 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 026034 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 026034 - Retry: 3
# Dados armazenados com sucesso - CVM 020982
# Dados armazenados com sucesso - CVM 021946
# Dados armazenados com sucesso - CVM 005312
# Dados armazenados com sucesso - CVM 001350
# Dados armazenados com sucesso - CVM 009040
# Dados armazenados com sucesso - CVM 009059
# Dados armazenados com sucesso - CVM 015539
# Dados armazenados com sucesso - CVM 025399
# Dados armazenados com sucesso - CVM 014621
# Dados armazenados com sucesso - CVM 017540
# Dados armazenados com sucesso - CVM 021180
# Dados armazenados com sucesso - CVM 001228
# Dados armazenados com sucesso - CVM 009083
# Dados armazenados com sucesso - CVM 022985
# Dados armazenados com sucesso - CVM 021334
# Dados armazenados com sucesso - CVM 025534
# Dados armazenados com sucesso - CVM 009199
# Dados armazenados com sucesso - CVM 004693
# Dados armazenados com sucesso - CVM 020125
# Dados armazenados com sucesso - CVM 011312
# Dados armazenados com sucesso - CVM 013560
# Dados armazenados com sucesso - CVM 009245
# Dados armazenados com sucesso - CVM 026441
# Dados armazenados com sucesso - CVM 026123
# Dados armazenados com sucesso - CVM 016942
# Dados armazenados com sucesso - CVM 009261
# Dados armazenados com sucesso - CVM 025550
# Dados armazenados com sucesso - CVM 021342
# Dados armazenados com sucesso - CVM 023507
# Dados armazenados com sucesso - CVM 013072
# Dados armazenados com sucesso - CVM 014826
# Dados armazenados com sucesso - CVM 024163
# Dados armazenados com sucesso - CVM 018414
# Dados armazenados com sucesso - CVM 022608
# Dados armazenados com sucesso - CVM 000094
# Dados armazenados com sucesso - CVM 015490
# Dados armazenados com sucesso - CVM 018708
# Dados armazenados com sucesso - CVM 012130
# Dados armazenados com sucesso - CVM 020729
# Dados armazenados com sucesso - CVM 003824
# Dados armazenados com sucesso - CVM 020478
# Dados armazenados com sucesso - CVM 012092
# Dados armazenados com sucesso - CVM 009490
# Dados armazenados com sucesso - CVM 009989
# Dados armazenados com sucesso - CVM 009512
# Dados armazenados com sucesso - CVM 024295
# Dados armazenados com sucesso - CVM 013994
# Dados armazenados com sucesso - CVM 014494
# Dados armazenados com sucesso - CVM 013595
# Dados armazenados com sucesso - CVM 025780
# Dados armazenados com sucesso - CVM 022187
# Dados armazenados com sucesso - CVM 009539
# Dados armazenados com sucesso - CVM 025089
# Dados armazenados com sucesso - CVM 020567
# Dados armazenados com sucesso - CVM 009601
# Dados armazenados com sucesso - CVM 013358
# Dados armazenados com sucesso - CVM 025070
# Dados armazenados com sucesso - CVM 013471
# Dados armazenados com sucesso - CVM 007005
# Dados armazenados com sucesso - CVM 015997
# Dados armazenados com sucesso - CVM 013447
# Dados armazenados com sucesso - CVM 019658
# Dados armazenados com sucesso - CVM 016659
# Dados armazenados com sucesso - CVM 013773
# Dados armazenados com sucesso - CVM 021776
# ERROR - Aquisicao de dados CVM - Code: 020362 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020362 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020362 - Retry: 3
# Dados armazenados com sucesso - CVM 015377
# Dados armazenados com sucesso - CVM 023728
# Dados armazenados com sucesso - CVM 024546
# Dados armazenados com sucesso - CVM 024236
# Dados armazenados com sucesso - CVM 001686
# Dados armazenados com sucesso - CVM 020346
# Dados armazenados com sucesso - CVM 001236
# Dados armazenados com sucesso - CVM 019232
# Dados armazenados com sucesso - CVM 018333
# Dados armazenados com sucesso - CVM 009784
# Dados armazenados com sucesso - CVM 020974
# Dados armazenados com sucesso - CVM 021482
# Dados armazenados com sucesso - CVM 022497
# Dados armazenados com sucesso - CVM 023302
# Dados armazenados com sucesso - CVM 019267
# Dados armazenados com sucesso - CVM 025038
# Dados armazenados com sucesso - CVM 022306
# Dados armazenados com sucesso - CVM 005258
# Dados armazenados com sucesso - CVM 025917
# Dados armazenados com sucesso - CVM 014109
# Dados armazenados com sucesso - CVM 018279
# Dados armazenados com sucesso - CVM 018023
# Dados armazenados com sucesso - CVM 018007
# Dados armazenados com sucesso - CVM 018015
# Dados armazenados com sucesso - CVM 012572
# Dados armazenados com sucesso - CVM 024821
# Dados armazenados com sucesso - CVM 003190
# Dados armazenados com sucesso - CVM 020893
# Dados armazenados com sucesso - CVM 022128
# Dados armazenados com sucesso - CVM 010030
# Dados armazenados com sucesso - CVM 017752
# Dados armazenados com sucesso - CVM 021636
# Dados armazenados com sucesso - CVM 017337
# Dados armazenados com sucesso - CVM 016250
# Dados armazenados com sucesso - CVM 012840
# Dados armazenados com sucesso - CVM 016535
# Dados armazenados com sucesso - CVM 013439
# Dados armazenados com sucesso - CVM 022330
# Dados armazenados com sucesso - CVM 020451
# Dados armazenados com sucesso - CVM 025801
# Dados armazenados com sucesso - CVM 007510
# Dados armazenados com sucesso - CVM 016306
# Dados armazenados com sucesso - CVM 023450
# Dados armazenados com sucesso - CVM 017450
# Dados armazenados com sucesso - CVM 003689
# Dados armazenados com sucesso - CVM 004189
# Dados armazenados com sucesso - CVM 014443
# Dados armazenados com sucesso - CVM 018848
# Dados armazenados com sucesso - CVM 027138
# ERROR - Aquisicao de dados CVM - Code: 012980 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 012980 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 012980 - Retry: 3
# Dados armazenados com sucesso - CVM 010260
# Dados armazenados com sucesso - CVM 018627
# Dados armazenados com sucesso - CVM 012696
# ERROR - Aquisicao de dados CVM - Code: 020532 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 020532 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 020532 - Retry: 3
# Dados armazenados com sucesso - CVM 004081
# Dados armazenados com sucesso - CVM 014516
# Dados armazenados com sucesso - CVM 016446
# Dados armazenados com sucesso - CVM 017892
# Dados armazenados com sucesso - CVM 013781
# Dados armazenados com sucesso - CVM 020516
# Dados armazenados com sucesso - CVM 010472
# Dados armazenados com sucesso - CVM 015261
# ERROR - Aquisicao de dados CVM - Code: 011681 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 011681 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 011681 - Retry: 3
# Dados armazenados com sucesso - CVM 003549
# Dados armazenados com sucesso - CVM 014664
# Dados armazenados com sucesso - CVM 018198
# Dados armazenados com sucesso - CVM 017906
# Dados armazenados com sucesso - CVM 003115
# Dados armazenados com sucesso - CVM 003140
# Dados armazenados com sucesso - CVM 017558
# Dados armazenados com sucesso - CVM 010588
# Dados armazenados com sucesso - CVM 025160
# Dados armazenados com sucesso - CVM 023221
# Dados armazenados com sucesso - CVM 010596
# Dados armazenados com sucesso - CVM 010642
# Dados armazenados com sucesso - CVM 015482
# Dados armazenados com sucesso - CVM 010669
# Dados armazenados com sucesso - CVM 004030
# Dados armazenados com sucesso - CVM 014117
# Dados armazenados com sucesso - CVM 010740
# Dados armazenados com sucesso - CVM 025003
# Dados armazenados com sucesso - CVM 022799
# Dados armazenados com sucesso - CVM 020745
# Dados armazenados com sucesso - CVM 024260
# Dados armazenados com sucesso - CVM 024252
# Dados armazenados com sucesso - CVM 020680
# Dados armazenados com sucesso - CVM 014710
# Dados armazenados com sucesso - CVM 022551
# Dados armazenados com sucesso - CVM 010880
# Dados armazenados com sucesso - CVM 009547
# Dados armazenados com sucesso - CVM 004057
# Dados armazenados com sucesso - CVM 010960
# Dados armazenados com sucesso - CVM 020966
# Dados armazenados com sucesso - CVM 001953
# Dados armazenados com sucesso - CVM 009415
# Dados armazenados com sucesso - CVM 024201
# Dados armazenados com sucesso - CVM 022594
# Dados armazenados com sucesso - CVM 001422
# Dados armazenados com sucesso - CVM 016586
# Dados armazenados com sucesso - CVM 016438
# Dados armazenados com sucesso - CVM 011010
# Dados armazenados com sucesso - CVM 021121
# Dados armazenados com sucesso - CVM 013030
# Dados armazenados com sucesso - CVM 009067
# Dados armazenados com sucesso - CVM 013986
# Dados armazenados com sucesso - CVM 021040
# Dados armazenados com sucesso - CVM 020257
# Dados armazenados com sucesso - CVM 016390
# Dados armazenados com sucesso - CVM 021717
# Dados armazenados com sucesso - CVM 006173
# Dados armazenados com sucesso - CVM 026077
# Dados armazenados com sucesso - CVM 011215
# Dados armazenados com sucesso - CVM 005983
# Dados armazenados com sucesso - CVM 022519
# Dados armazenados com sucesso - CVM 011169
# Dados armazenados com sucesso - CVM 020435
# Dados armazenados com sucesso - CVM 011207
# Dados armazenados com sucesso - CVM 014133
# Dados armazenados com sucesso - CVM 020800
# Dados armazenados com sucesso - CVM 025844
# Dados armazenados com sucesso - CVM 011223
# Dados armazenados com sucesso - CVM 011231
# Dados armazenados com sucesso - CVM 017604
# Dados armazenados com sucesso - CVM 011258
# Dados armazenados com sucesso - CVM 017671
# Dados armazenados com sucesso - CVM 017655
# Dados armazenados com sucesso - CVM 011320
# Dados armazenados com sucesso - CVM 017213
# Dados armazenados com sucesso - CVM 017701
# Dados armazenados com sucesso - CVM 017418
# Dados armazenados com sucesso - CVM 019917
# Dados armazenados com sucesso - CVM 021148
# Dados armazenados com sucesso - CVM 022136
# Dados armazenados com sucesso - CVM 026000
# Dados armazenados com sucesso - CVM 007544
# Dados armazenados com sucesso - CVM 024929
# Dados armazenados com sucesso - CVM 017078
# Dados armazenados com sucesso - CVM 017221
# Dados armazenados com sucesso - CVM 022454
# Dados armazenados com sucesso - CVM 021768
# Dados armazenados com sucesso - CVM 019992
# Dados armazenados com sucesso - CVM 025208
# ERROR - Aquisicao de dados CVM - Code: 011452 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 011452 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 011452 - Retry: 3
# Dados armazenados com sucesso - CVM 018376
# Dados armazenados com sucesso - CVM 011479
# ERROR - Aquisicao de dados CVM - Code: 011495 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 011495 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 011495 - Retry: 3
# Dados armazenados com sucesso - CVM 008192
# Dados armazenados com sucesso - CVM 021130
# Dados armazenados com sucesso - CVM 019330
# Dados armazenados com sucesso - CVM 011517
# ERROR - Aquisicao de dados CVM - Code: 011525 - Retry: 1
# ERROR - Aquisicao de dados CVM - Code: 011525 - Retry: 2
# ERROR - Aquisicao de dados CVM - Code: 011525 - Retry: 3
# Dados armazenados com sucesso - CVM 006343
# Dados armazenados com sucesso - CVM 018465
# Dados armazenados com sucesso - CVM 011584
# Dados armazenados com sucesso - CVM 014753
# Dados armazenados com sucesso - CVM 022780
# Dados armazenados com sucesso - CVM 026050
# Dados armazenados com sucesso - CVM 011592
# Dados armazenados com sucesso - CVM 019887
# Dados armazenados com sucesso - CVM 016624
# Dados armazenados com sucesso - CVM 014320
# Dados armazenados com sucesso - CVM 012220
# Dados armazenados com sucesso - CVM 004170
# Dados armazenados com sucesso - CVM 014028
# Dados armazenados com sucesso - CVM 016225
# Dados armazenados com sucesso - CVM 020028
# Dados armazenados com sucesso - CVM 024716
# Dados armazenados com sucesso - CVM 018694
# Dados armazenados com sucesso - CVM 018686
# Dados armazenados com sucesso - CVM 011703
# Dados armazenados com sucesso - CVM 014540
# Dados armazenados com sucesso - CVM 021440
# Dados armazenados com sucesso - CVM 005991
# Dados armazenados com sucesso - CVM 010227
# Dados armazenados com sucesso - CVM 022772
# Dados armazenados com sucesso - CVM 025763
# Dados armazenados com sucesso - CVM 024805
# Dados armazenados com sucesso - CVM 019950
# Dados armazenados com sucesso - CVM 025682
# Dados armazenados com sucesso - CVM 020702
# Dados armazenados com sucesso - CVM 017710
# Dados armazenados com sucesso - CVM 011754
# Dados armazenados com sucesso - CVM 011762
# Dados armazenados com sucesso - CVM 025895
# Dados armazenados com sucesso - CVM 005410
# Dados armazenados com sucesso - CVM 011800
# Dados armazenados com sucesso - CVM 025518
# Dados armazenados com sucesso - CVM 011991
# Dados armazenados com sucesso - CVM 014346
# Dados armazenados com sucesso - CVM 010294
# Dados armazenados com sucesso - CVM 014397
# Dados armazenados com sucesso - CVM 026247
# Dados armazenados com sucesso - CVM 023590
# Dados armazenados com sucesso - CVM 011070
# Dados armazenados com sucesso - CVM 023779
# Dados armazenados com sucesso - CVM 000140
# Dados armazenados com sucesso - CVM 016705
# Dados armazenados com sucesso - CVM 021016
# Dados armazenados com sucesso - CVM 017361
# Dados armazenados com sucesso - CVM 024317
